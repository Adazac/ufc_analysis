# %% [markdown]
# # This notebook analyzes UFC data

# %%
import pandas as pd
import numpy as np
pd.options.display.max_colwidth = 100

pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ufc_data = pd.read_csv("ufc_data.csv")

# %%
ufc_data.head()
# Out:
#              Fighter A          Fighter B Result  Weightclass  Rounds  \
# 0        Marcin Tybura        Tai Tuivasa    win        265.0       5
# 1         Bryan Battle         Ange Loosa     NC        170.0       3
# 2     Ovince St. Preux  Kennedy Nzechukwu    win        205.0       3
# 3  Christian Rodriguez    Isaac Dulgarian    win        145.0       3
# 4        Macy Chiasson     Pannie Kianzad    win        135.0       3
#
#       Venue        Date                          Location     Billing  \
# 0  UFC Apex  2024-03-16  Las Vegas, Nevada, United States  Main Event
# 1  UFC Apex  2024-03-16  Las Vegas, Nevada, United States     Co-Main
# 2  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 3  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 4  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
#
#                             Event Name        Referee          Description  \
# 0  UFC Fight Night: Tuivasa vs. Tybura      Herb Dean     Rear Naked Choke
# 1  UFC Fight Night: Tuivasa vs. Tybura   Mike Beltran  Accidental Eye Poke
# 2  UFC Fight Night: Tuivasa vs. Tybura     Mark Smith                Split
# 3  UFC Fight Night: Tuivasa vs. Tybura  Chris Tognoni                Split
# 4  UFC Fight Night: Tuivasa vs. Tybura     Mark Smith     Rear Naked Choke
#
#        Method  Finish  Odds A Title A  Weight A  Age A  Height A  Reach A  \
# 0  Submission       1    -105     NaN     247.0     38     191.0    198.0
# 1  No Contest       0    -180     NaN     170.0     29     185.0    196.0
# 2    Decision       0     500     NaN     206.0     40     191.0    203.0
# 3    Decision       0     165     NaN     145.0     26     170.0    180.0
# 4  Submission       1    -230     NaN     135.5     32     180.0    183.0
#
#    KO win A  KO loss A  Sub win A  Sub loss A  Dec win A  Dec loss A  Draws A  \
# 0         9          5          6           0          9           3        0
# 1         3          0          5           1          2           1        0
# 2        12          5          8           3          6           9        0
# 3         3          0          4           0          3           1        0
# 4         2          1          2           1          4           1        0
#
#    UFC win A  UFC loss A  UFC draws A  Nationality A       Nick A  \
# 0         11           7            0         Poland        Tybur
# 1          5           1            0  United States  The Butcher
# 2         14          12            0  United States          OSP
# 3          3           1            0  United States       CeeRod
# 4          6           3            0  United States          NaN
#
#           Odds cat A  Odds B Title B  Weight B  Age B  Height B  Reach B  \
# 0          Near Even    -115     NaN     265.5     31     188.0    191.0
# 1    Slight Favorite     150     NaN     171.0     29     178.0    188.0
# 2     Heavy Underdog    -700     NaN     205.0     31     196.0    211.0
# 3    Slight Underdog    -200     NaN     145.5     27     170.0    180.0
# 4  Moderate Favorite     190     NaN     136.0     32     170.0    168.0
#
#    KO win B  KO loss B  Sub win B  Sub loss B  Dec win B  Dec loss B  Draws B  \
# 0        13          3          0           2          1           1        0
# 1         5          0          1           0          4           3        0
# 2         8          2          1           1          3           1        0
# 3         4          0          2           0          0           0        0
# 4         3          1          0           2         13           4        0
#
#    UFC win B  UFC loss B  UFC draws B                          Nationality B  \
# 0          8           6            0                              Australia
# 1          2           1            0  Congo, The Democratic Republic of the
# 2          6           4            0                          United States
# 3          1           0            0                          United States
# 4          5           4            0                                 Sweden
#
#                Nick B         Odds cat B
# 0             Bam Bam          Near Even
# 1      The Last Ninja    Slight Underdog
# 2     American Savage      Huge Favorite
# 3  The MidWest Choppa  Moderate Favorite
# 4              Banzai    Slight Underdog

# %%
ufc_data.describe(include="all")
# Out:
#          Fighter A        Fighter B Result  Weightclass       Rounds  \
# count         7294             7294   7294  7294.000000  7294.000000
# unique        1632             2179      3          NaN          NaN
# top     Jim Miller  Jeremy Stephens    win          NaN          NaN
# freq            27               19   7157          NaN          NaN
# mean           NaN              NaN    NaN   168.448862     3.180971
# std            NaN              NaN    NaN    37.936675     0.573791
# min            NaN              NaN    NaN   115.000000     3.000000
# 25%            NaN              NaN    NaN   145.000000     3.000000
# 50%            NaN              NaN    NaN   155.000000     3.000000
# 75%            NaN              NaN    NaN   185.000000     3.000000
# max            NaN              NaN    NaN   265.000000     5.000000
#
#            Venue        Date                          Location Billing  \
# count       7294        7294                              7294    7294
# unique       248         644                               175       5
# top     UFC APEX  2016-11-19  Las Vegas, Nevada, United States  Prelim
# freq         764          25                              2449    3957
# mean         NaN         NaN                               NaN     NaN
# std          NaN         NaN                               NaN     NaN
# min          NaN         NaN                               NaN     NaN
# 25%          NaN         NaN                               NaN     NaN
# 50%          NaN         NaN                               NaN     NaN
# 75%          NaN         NaN                               NaN     NaN
# max          NaN         NaN                               NaN     NaN
#
#                                   Event Name    Referee Description    Method  \
# count                                   7294       7192        7265      7294
# unique                                   649        209         408         4
# top     UFC Fight Night: Aspinall vs. Tybura  Herb Dean   Unanimous  Decision
# freq                                      15       1092        2617      3418
# mean                                     NaN        NaN         NaN       NaN
# std                                      NaN        NaN         NaN       NaN
# min                                      NaN        NaN         NaN       NaN
# 25%                                      NaN        NaN         NaN       NaN
# 50%                                      NaN        NaN         NaN       NaN
# 75%                                      NaN        NaN         NaN       NaN
# max                                      NaN        NaN         NaN       NaN
#
#              Finish       Odds A   Title A     Weight A        Age A  \
# count   7294.000000  7294.000000       328  7294.000000  7294.000000
# unique          NaN          NaN         4          NaN          NaN
# top             NaN          NaN  Champion          NaN          NaN
# freq            NaN          NaN       188          NaN          NaN
# mean       0.877296  -131.491363       NaN   167.434234    29.384974
# std        1.032661   267.531927       NaN    34.719026     4.016096
# min        0.000000 -2200.000000       NaN   113.000000    18.000000
# 25%        0.000000  -270.000000       NaN   145.000000    27.000000
# 50%        1.000000  -155.000000       NaN   156.000000    29.000000
# 75%        2.000000   115.000000       NaN   185.000000    32.000000
# max        5.000000   950.000000       NaN   267.500000    47.000000
#
#            Height A     Reach A     KO win A    KO loss A    Sub win A  \
# count   7294.000000  7294.00000  7294.000000  7294.000000  7294.000000
# unique          NaN         NaN          NaN          NaN          NaN
# top             NaN         NaN          NaN          NaN          NaN
# freq            NaN         NaN          NaN          NaN          NaN
# mean     178.739649   183.69737     5.839183     1.007266     4.399781
# std        9.037656    10.94614     4.257036     1.341294     4.177507
# min      152.000000   149.00000     0.000000     0.000000     0.000000
# 25%      173.000000   178.00000     3.000000     0.000000     1.000000
# 50%      178.000000   183.00000     5.000000     1.000000     3.000000
# 75%      185.000000   191.00000     8.000000     1.000000     6.000000
# max      214.000000   221.00000    29.000000    14.000000    46.000000
#
#          Sub loss A    Dec win A   Dec loss A      Draws A    UFC win A  \
# count   7294.000000  7294.000000  7294.000000  7294.000000  7294.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       0.957774     3.757335     1.725802     0.157938     3.574993
# std        1.422093     3.040124     1.905688     0.473058     3.789550
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%        0.000000     1.000000     0.000000     0.000000     1.000000
# 50%        0.000000     3.000000     1.000000     0.000000     2.000000
# 75%        1.000000     5.000000     3.000000     0.000000     5.000000
# max       14.000000    17.000000    16.000000     7.000000    25.000000
#
#          UFC loss A  UFC draws A  Nationality A  Nick A         Odds cat A  \
# count   7294.000000  7294.000000           7294    5737               7294
# unique          NaN          NaN             90    1067                 10
# top             NaN          NaN  United States  Cowboy  Moderate Favorite
# freq            NaN          NaN           3844      35               2010
# mean       1.867562     0.040444            NaN     NaN                NaN
# std        2.151536     0.205194            NaN     NaN                NaN
# min        0.000000     0.000000            NaN     NaN                NaN
# 25%        0.000000     0.000000            NaN     NaN                NaN
# 50%        1.000000     0.000000            NaN     NaN                NaN
# 75%        3.000000     0.000000            NaN     NaN                NaN
# max       16.000000     2.000000            NaN     NaN                NaN
#
#              Odds B     Title B     Weight B        Age B     Height B  \
# count   7294.000000         328  7294.000000  7294.000000  7294.000000
# unique          NaN           4          NaN          NaN          NaN
# top             NaN  Challenger          NaN          NaN          NaN
# freq            NaN         183          NaN          NaN          NaN
# mean      71.211681         NaN   167.406005    30.148204   178.485096
# std      239.588910         NaN    34.700926     4.172918     8.853481
# min    -1400.000000         NaN   112.000000    18.000000   152.000000
# 25%     -137.500000         NaN   145.000000    27.000000   173.000000
# 50%      130.000000         NaN   156.000000    30.000000   178.000000
# 75%      220.000000         NaN   185.000000    33.000000   185.000000
# max     2225.000000         NaN   266.000000    47.000000   214.000000
#
#             Reach B     KO win B    KO loss B    Sub win B   Sub loss B  \
# count   7294.000000  7294.000000  7294.000000  7294.000000  7294.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     183.227432     5.779819     1.179737     4.592953     1.109268
# std       10.427629     4.398471     1.460075     4.364581     1.538211
# min      149.000000     0.000000     0.000000     0.000000     0.000000
# 25%      177.000000     3.000000     0.000000     2.000000     0.000000
# 50%      183.000000     5.000000     1.000000     4.000000     1.000000
# 75%      191.000000     8.000000     2.000000     6.000000     2.000000
# max      215.000000    31.000000    14.000000    47.000000    12.000000
#
#           Dec win B   Dec loss B      Draws B    UFC win B   UFC loss B  \
# count   7294.000000  7294.000000  7294.000000  7294.000000  7294.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       3.808061     1.882232     0.197834     3.383055     2.004387
# std        3.184816     2.038093     0.587768     3.928920     2.298208
# min        0.000000     0.000000     0.000000     0.000000     0.000000
# 25%        1.000000     0.000000     0.000000     0.000000     0.000000
# 50%        3.000000     1.000000     0.000000     2.000000     1.000000
# 75%        5.000000     3.000000     0.000000     5.000000     3.000000
# max       21.000000    15.000000     8.000000    24.000000    17.000000
#
#         UFC draws B  Nationality B       Nick B         Odds cat B
# count   7294.000000           7294         5673               7294
# unique          NaN            100         1338                 10
# top             NaN  United States  The Spartan  Moderate Underdog
# freq            NaN           4045           35               1752
# mean       0.041678            NaN          NaN                NaN
# std        0.214429            NaN          NaN                NaN
# min        0.000000            NaN          NaN                NaN
# 25%        0.000000            NaN          NaN                NaN
# 50%        0.000000            NaN          NaN                NaN
# 75%        0.000000            NaN          NaN                NaN
# max        2.000000            NaN          NaN                NaN

# %%
ufc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7294 entries, 0 to 7293
# Data columns (total 52 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fighter A      7294 non-null   object
#  1   Fighter B      7294 non-null   object
#  2   Result         7294 non-null   object
#  3   Weightclass    7294 non-null   float64
#  4   Rounds         7294 non-null   int64
#  5   Venue          7294 non-null   object
#  6   Date           7294 non-null   object
#  7   Location       7294 non-null   object
#  8   Billing        7294 non-null   object
#  9   Event Name     7294 non-null   object
#  10  Referee        7192 non-null   object
#  11  Description    7265 non-null   object
#  12  Method         7294 non-null   object
#  13  Finish         7294 non-null   int64
#  14  Odds A         7294 non-null   int64
#  15  Title A        328 non-null    object
#  16  Weight A       7294 non-null   float64
#  17  Age A          7294 non-null   int64
#  18  Height A       7294 non-null   float64
#  19  Reach A        7294 non-null   float64
#  20  KO win A       7294 non-null   int64
#  21  KO loss A      7294 non-null   int64
#  22  Sub win A      7294 non-null   int64
#  23  Sub loss A     7294 non-null   int64
#  24  Dec win A      7294 non-null   int64
#  25  Dec loss A     7294 non-null   int64
#  26  Draws A        7294 non-null   int64
#  27  UFC win A      7294 non-null   int64
#  28  UFC loss A     7294 non-null   int64
#  29  UFC draws A    7294 non-null   int64
#  30  Nationality A  7294 non-null   object
#  31  Nick A         5737 non-null   object
#  32  Odds cat A     7294 non-null   object
#  33  Odds B         7294 non-null   int64
#  34  Title B        328 non-null    object
#  35  Weight B       7294 non-null   float64
#  36  Age B          7294 non-null   int64
#  37  Height B       7294 non-null   float64
#  38  Reach B        7294 non-null   float64
#  39  KO win B       7294 non-null   int64
#  40  KO loss B      7294 non-null   int64
#  41  Sub win B      7294 non-null   int64
#  42  Sub loss B     7294 non-null   int64
#  43  Dec win B      7294 non-null   int64
#  44  Dec loss B     7294 non-null   int64
#  45  Draws B        7294 non-null   int64
#  46  UFC win B      7294 non-null   int64
#  47  UFC loss B     7294 non-null   int64
#  48  UFC draws B    7294 non-null   int64
#  49  Nationality B  7294 non-null   object
#  50  Nick B         5673 non-null   object
#  51  Odds cat B     7294 non-null   object
# dtypes: float64(7), int64(26), object(19)
# memory usage: 2.9+ MB

# %% [markdown]
# ## Research Questions

# %% [markdown]
# ### 1. How do physical attributes affect the result?

# %% [markdown]
# #### First we check if height difference plays a significant role in match result.

# %%
df_win = ufc_data[ufc_data["Result"] == "win"]
df_win.head()
# Out:
#              Fighter A          Fighter B Result  Weightclass  Rounds  \
# 0        Marcin Tybura        Tai Tuivasa    win        265.0       5
# 2     Ovince St. Preux  Kennedy Nzechukwu    win        205.0       3
# 3  Christian Rodriguez    Isaac Dulgarian    win        145.0       3
# 4        Macy Chiasson     Pannie Kianzad    win        135.0       3
# 5   Gerald Meerschaert    Bryan Barberena    win        185.0       3
#
#       Venue        Date                          Location     Billing  \
# 0  UFC Apex  2024-03-16  Las Vegas, Nevada, United States  Main Event
# 2  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 3  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 4  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 5  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
#
#                             Event Name        Referee       Description  \
# 0  UFC Fight Night: Tuivasa vs. Tybura      Herb Dean  Rear Naked Choke
# 2  UFC Fight Night: Tuivasa vs. Tybura     Mark Smith             Split
# 3  UFC Fight Night: Tuivasa vs. Tybura  Chris Tognoni             Split
# 4  UFC Fight Night: Tuivasa vs. Tybura     Mark Smith  Rear Naked Choke
# 5  UFC Fight Night: Tuivasa vs. Tybura      Herb Dean  Rear Naked Choke
#
#        Method  Finish  Odds A Title A  Weight A  Age A  Height A  Reach A  \
# 0  Submission       1    -105     NaN     247.0     38     191.0    198.0
# 2    Decision       0     500     NaN     206.0     40     191.0    203.0
# 3    Decision       0     165     NaN     145.0     26     170.0    180.0
# 4  Submission       1    -230     NaN     135.5     32     180.0    183.0
# 5  Submission       2    -250     NaN     185.5     36     185.0    197.0
#
#    KO win A  KO loss A  Sub win A  Sub loss A  Dec win A  Dec loss A  Draws A  \
# 0         9          5          6           0          9           3        0
# 2        12          5          8           3          6           9        0
# 3         3          0          4           0          3           1        0
# 4         2          1          2           1          4           1        0
# 5         6          4         27           8          2           5        0
#
#    UFC win A  UFC loss A  UFC draws A  Nationality A  Nick A  \
# 0         11           7            0         Poland   Tybur
# 2         14          12            0  United States     OSP
# 3          3           1            0  United States  CeeRod
# 4          6           3            0  United States     NaN
# 5         10           9            0  United States     GM3
#
#           Odds cat A  Odds B Title B  Weight B  Age B  Height B  Reach B  \
# 0          Near Even    -115     NaN     265.5     31     188.0    191.0
# 2     Heavy Underdog    -700     NaN     205.0     31     196.0    211.0
# 3    Slight Underdog    -200     NaN     145.5     27     170.0    180.0
# 4  Moderate Favorite     190     NaN     136.0     32     170.0    168.0
# 5  Moderate Favorite     200     NaN     186.0     34     183.0    183.0
#
#    KO win B  KO loss B  Sub win B  Sub loss B  Dec win B  Dec loss B  Draws B  \
# 0        13          3          0           2          1           1        0
# 2         8          2          1           1          3           1        0
# 3         4          0          2           0          0           0        0
# 4         3          1          0           2         13           4        0
# 5        11          2          2           3          5           6        0
#
#    UFC win B  UFC loss B  UFC draws B  Nationality B              Nick B  \
# 0          8           6            0      Australia             Bam Bam
# 2          6           4            0  United States     American Savage
# 3          1           0            0  United States  The MidWest Choppa
# 4          5           4            0         Sweden              Banzai
# 5          9           9            0  United States             Bam Bam
#
#           Odds cat B
# 0          Near Even
# 2      Huge Favorite
# 3  Moderate Favorite
# 4    Slight Underdog
# 5  Moderate Underdog

# %%
df_win.loc[:, "Height Diff"] = df_win['Height A'] - df_win['Height B']
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_7020\1960808998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win.loc[:, "Height Diff"] = df_win['Height A'] - df_win['Height B']

# %%
bins = [-17.5, -12.5, -7.5, -2.5, 2.5, 7.5, 12.5, 17.5]
sns.histplot(df_win, x = "Height Diff", bins=bins, stat='percent')
plt.xlabel('Height difference in centimeters')
plt.ylabel('Frequency')
plt.xticks(ticks=bins, labels=bins)
plt.show()

# %%
counts, _ = np.histogram(df_win['Height Diff'], bins=bins)
print("Counts: ", counts, "Percentage: ", counts/len(df_win['Height Diff']))
# Out:
# Counts:  [ 156  596 1568 2244 1675  673  170] Percentage:  [0.02179684 0.08327512 0.21908621 0.31353919 0.23403661 0.09403381
#  0.02375297]

# %%
taller = (df_win['Height A'] > df_win['Height B']).sum()
smaller = (df_win['Height A'] < df_win['Height B']).sum()
taller_p = taller / ( taller + smaller)
smaller_p = smaller / ( taller + smaller)
print(taller_p, smaller_p)
# Out:
# 0.5179961089494164 0.48200389105058367

# %% [markdown]
# The graph above shows the distribution of height difference for the winning fighter. We can see that the graph is quite symetrical with a small skewness to the right, indicating that there is a tiny difference in the chances of fighter winning if he is taller.

# %% [markdown]
# #### Now we check if reach difference plays a significant role in match result.

# %%
df_win.loc[:, "Reach Diff"] = df_win['Reach A'] - df_win['Reach B']
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_7020\476300333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win.loc[:, "Reach Diff"] = df_win['Reach A'] - df_win['Reach B']

# %%
bins = [-22.5, -17.5, -12.5, -7.5, -2.5, 2.5, 7.5, 12.5, 17.5, 22.5]
sns.histplot(df_win, x = "Reach Diff", bins=bins, stat='percent')
plt.xlabel('Reach difference in centimeters')
plt.ylabel('Frequency')
plt.xticks(ticks=bins, labels=bins)
plt.show()

# %%
counts, _ = np.histogram(df_win['Reach Diff'], bins=bins)
counts
# Out:
# array([  98,  327,  764, 1346, 1804, 1368,  838,  380,  157], dtype=int64)

# %%
longer = (df_win['Reach A'] > df_win['Reach B']).sum()
shorter = (df_win['Reach A'] < df_win['Reach B']).sum()
longer_p = longer / ( longer + shorter)
shorter_p = shorter / ( longer + shorter)
print(longer_p, shorter_p)
# Out:
# 0.5268751897965381 0.47312481020346187

# %% [markdown]
# This graph looks similar to the one with height, expect we cant see the change until 7.5 centimeters difference.

# %% [markdown]
# #### Now we check if age difference affects match result.

# %%
df_win.loc[:, "Age Diff"] = df_win['Age A'] - df_win['Age B']
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_7020\4025196989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win.loc[:, "Age Diff"] = df_win['Age A'] - df_win['Age B']

# %%
bins = [-17.5, -12.5, -7.5, -2.5, 2.5, 7.5, 12.5, 17.5]
sns.histplot(df_win, x = "Age Diff", bins=bins, stat="percent")
plt.xlabel('Age difference in centimeters')
plt.ylabel('Frequency')
plt.xticks(ticks=bins, labels=bins)
plt.show()

# %%
counts, _ = np.histogram(df_win['Age Diff'], bins=bins)
print("Counts: ", counts, "Percentage: ", counts/len(df_win['Age Diff']))
# Out:
# Counts:  [  94  622 1961 2610 1472  364   34] Percentage:  [0.01313399 0.08690792 0.27399748 0.36467794 0.20567277 0.0508593
#  0.00475059]

# %%
older = (df_win['Age A'] > df_win['Age B']).sum()
younger = (df_win['Age A'] < df_win['Age B']).sum()
older_p = older / ( older + younger)
younger_p = younger / ( older + younger)
print(older_p, younger_p)
# Out:
# 0.434265944645006 0.565734055354994

# %% [markdown]
# We can see that there is a big difference in Age when it comes to chances of winning a fight. Younger fighters are more likely to win a fight with a probability of 56.6%.

# %%
data = {
    "Win": [taller_p, longer_p, older_p],
    "Lose": [smaller_p, shorter_p, younger_p]
}
chance_df_win = pd.DataFrame(data)
chance_df_win.index = ["Height", "Reach", "Age"]
chance_df_win.plot(kind='bar')
plt.xlabel('Metric')
plt.ylabel('Frequency')
plt.title('Chances of fighter with higher Height, Reach and Age to win')
plt.xticks(rotation = 0)
plt.show()

# %%
df_win['Height Comparison'] = np.where(df_win['Height A'] > df_win['Height B'], 'Taller', 
                             np.where(df_win['Height A'] < df_win['Height B'], 'Smaller', 'Same'))
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\1938230907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win['Height Comparison'] = np.where(df_win['Height A'] > df_win['Height B'], 'Taller',

# %%
df_win['Reach Comparison'] = np.where(df_win['Reach A'] > df_win['Reach B'], 'Longer', 
                             np.where(df_win['Reach A'] < df_win['Reach B'], 'Shorter', 'Same'))
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\2393522247.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win['Reach Comparison'] = np.where(df_win['Reach A'] > df_win['Reach B'], 'Longer',

# %%
df_win['Age Comparison'] = np.where(df_win['Age A'] > df_win['Age B'], 'Older', 
                             np.where(df_win['Age A'] < df_win['Age B'], 'Younger', 'Same'))
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\962340197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win['Age Comparison'] = np.where(df_win['Age A'] > df_win['Age B'], 'Older',

# %%
df_win["Age Comparison"]
# Out:
# 0         Older
# 2         Older
# 3       Younger
# 4          Same
# 5         Older
#          ...
# 7289      Older
# 7290      Older
# 7291      Older
# 7292    Younger
# 7293    Younger
# Name: Age Comparison, Length: 7157, dtype: object

# %%
comp_table = df_win.groupby(["Height Comparison", "Reach Comparison", "Age Comparison"])["Result"].count().reset_index()
comp_table.sort_values("Result", ascending=False)
# Out:
#    Height Comparison Reach Comparison Age Comparison  Result
# 20            Taller           Longer        Younger    1341
# 17           Smaller          Shorter        Younger     938
# 15           Smaller          Shorter          Older     933
# 18            Taller           Longer          Older     809
# 11           Smaller           Longer        Younger     373
# 26            Taller          Shorter        Younger     370
# 9            Smaller           Longer          Older     280
# 24            Taller          Shorter          Older     253
# 2               Same           Longer        Younger     228
# 8               Same          Shorter        Younger     216
# 0               Same           Longer          Older     205
# 6               Same          Shorter          Older     169
# 16           Smaller          Shorter           Same     153
# 19            Taller           Longer           Same     145
# 14           Smaller             Same        Younger     120
# 23            Taller             Same        Younger     113
# 12           Smaller             Same          Older     103
# 21            Taller             Same          Older      94
# 5               Same             Same        Younger      62
# 10           Smaller           Longer           Same      58
# 25            Taller          Shorter           Same      52
# 3               Same             Same          Older      41
# 7               Same          Shorter           Same      32
# 1               Same           Longer           Same      31
# 22            Taller             Same           Same      18
# 13           Smaller             Same           Same      15
# 4               Same             Same           Same       5

# %% [markdown]
# As expected, we can see that the most populated group to win a fight in ufc is a Taller, Longer and Younger fighter.

# %% [markdown]
# ### 2. How do other characterictics affect the result?

# %% [markdown]
# #### Are there some nations that are exceptionaly better than others?

# %% [markdown]
# First we need to extract unique values.

# %%
nations_list = pd.concat([df_win["Nationality A"], df_win["Nationality B"]], ignore_index=True)
nations_list = nations_list.unique()
nations_list.shape
# Out:
# (102,)

# %%
type(nations_list)
# Out:
# numpy.ndarray

# %% [markdown]
# Now we calculate the number of wins and losses for each nation. In the A column there are wins, in B column there are losses.

# %%
nations_a = df_win.groupby(["Nationality A"])["Result"].count().reset_index()
nations_b = df_win.groupby(["Nationality B"])["Result"].count().reset_index()

# %% [markdown]
# Create a DataFrame "nations_record" with nations wins and losses.

# %%
# Set 'Nationality A' and 'Nationality B' column as index
nations_a.set_index('Nationality A', inplace=True)
nations_b.set_index('Nationality B', inplace=True)

# Create a DataFrame containing number of wins corresponding to each nation
nations_record = pd.DataFrame(index=nations_list)
nations_record['Wins'] = nations_a['Result'].reindex(nations_list, fill_value=0)
nations_record['Losses'] = nations_b['Result'].reindex(nations_list, fill_value=0)

# %% [markdown]
# Create a "Total" column, with number of all fights of the nation, then filter the DataFrame for nations with 50 or more fights.

# %%
nations_record['Total'] = nations_record['Wins'] + nations_record['Losses']

# %%
nations_record = nations_record[nations_record["Total"] >= 100]

# %%
nations_record.sort_values("Total", ascending=False)
# Out:
#                Wins  Losses  Total
# United States  3770    3973   7743
# Brazil         1133     994   2127
# Canada          286     296    582
# England         236     224    460
# Russia          240     137    377
# Australia       139     144    283
# Japan            95     153    248
# Mexico          105      92    197
# Poland           95      91    186
# Sweden           71      74    145
# France           80      55    135
# China            69      63    132
# South Korea      65      62    127

# %% [markdown]
# There are 13 nations with 50 or more fights in our data.

# %%
nations_record['Win Percentage'] = nations_record['Wins'] / nations_record['Total']

# %%
nations_record["Win Percentage"].plot(kind='bar')
plt.xlabel('Nation')
plt.ylabel('Win Percentage')
plt.title('Win percentage of each Nation')
plt.xticks(rotation = 60)
plt.axhline(y=0.5, color='r', linestyle='-', linewidth=2)
plt.show()

# %% [markdown]
# From this graph we can see that most nations have a success rate around the 50% mark. There are few outliers with Russia success rate about 63%, France right under 60% and Japan about 38%.
#
# We have to note that there is a big difference between number of fights each nation has with United States 7743 and Brazil 2127. Other 11 countries are between 582 and 127.

# %% [markdown]
# For the number of Brazillian fighters, we have to state that their success rate is impressive as well.

# %% [markdown]
# #### Who is more likely to win a title fight?

# %%
df_win[["Title A", "Title B"]].value_counts()
# Out:
# Title A           Title B
# Champion          Challenger          174
# Challenger        Champion             76
# Vacant            Vacant               51
# Champion          Interim Champion      9
# Interim Champion  Champion              7
#                   Challenger            4
# Challenger        Interim Champion      1
# Name: count, dtype: int64

# %%
sizes = [183, 83]
labels = ['Champion Wins', 'Champion Losses']

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('')
plt.show()

# %% [markdown]
# Champions won 183 fights and only lost 83 fights having 68.8% success rate in title fights.

# %% [markdown]
# #### Is there a benefit in missing scheduled weight?

# %% [markdown]
# There is a rumor in the MMA community that missing weight, helps fighters win, because they can be heavier in the fight. MMA organizations aknowledge this advantage by charging the fighter part of his purse if he misses weight.
#
# But there is also a possibility, that fighters who dont manage to make weight might be negatively affected by some other factors or the weight cut itself.

# %% [markdown]
# To determine whether a fighter missed weight, we need to differentiate between title, non title fights and "catchweight" fights. In title and catchweight fights there is no tolerance, in normal fights there is 1 pound tolerance.

# %%
df_win[["Weightclass", "Weight A", "Weight B", "Title A", "Title B"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7157 entries, 0 to 7293
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Weightclass  7157 non-null   float64
#  1   Weight A     7157 non-null   float64
#  2   Weight B     7157 non-null   float64
#  3   Title A      322 non-null    object
#  4   Title B      322 non-null    object
# dtypes: float64(3), object(2)
# memory usage: 335.5+ KB

# %% [markdown]
# These are standard MMA categories (115, 125, 135, 145, 155, 170, 185, 205, 265), all the others are catchweight.

# %%
df_win["Weightclass"].value_counts()
# Out:
# Weightclass
# 155.0    1235
# 170.0    1225
# 185.0     944
# 135.0     814
# 145.0     727
# 205.0     650
# 265.0     614
# 125.0     529
# 115.0     288
# 140.0      18
# 160.0      10
# 150.0       8
# 158.0       7
# 195.0       7
# 138.0       6
# 180.0       5
# 130.0       4
# 148.0       4
# 174.0       3
# 175.0       3
# 127.0       3
# 190.0       3
# 149.0       3
# 165.0       3
# 215.0       3
# 136.0       2
# 120.0       2
# 129.0       2
# 139.0       2
# 128.0       2
# 172.0       2
# 176.0       2
# 157.0       2
# 141.0       2
# 177.0       2
# 159.0       2
# 146.0       1
# 211.0       1
# 220.0       1
# 197.0       1
# 208.0       1
# 189.0       1
# 187.0       1
# 183.0       1
# 123.0       1
# 143.0       1
# 142.0       1
# 163.0       1
# 186.0       1
# 137.0       1
# 188.0       1
# 147.0       1
# 156.0       1
# 118.0       1
# 173.0       1
# Name: count, dtype: int64

# %% [markdown]
# We create new column "Tolerance" and fill it with corresponding values.

# %%
df_win.loc[~df_win["Weightclass"].isin([115, 125, 135, 145, 155, 170, 185, 205, 265]), "Tolerance"] = 0
df_win.loc[df_win["Weightclass"].isin([115, 125, 135, 145, 155, 170, 185, 205, 265]), "Tolerance"] = 1
df_win.loc[~df_win["Title A"].isnull(), "Tolerance"] = 0
df_win.loc[~df_win["Title B"].isnull(), "Tolerance"] = 0
df_win.head()
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\1187809057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win.loc[~df_win["Weightclass"].isin([115, 125, 135, 145, 155, 170, 185, 205, 265]), "Tolerance"] = 0
#              Fighter A          Fighter B Result  Weightclass  Rounds  \
# 0        Marcin Tybura        Tai Tuivasa    win        265.0       5
# 2     Ovince St. Preux  Kennedy Nzechukwu    win        205.0       3
# 3  Christian Rodriguez    Isaac Dulgarian    win        145.0       3
# 4        Macy Chiasson     Pannie Kianzad    win        135.0       3
# 5   Gerald Meerschaert    Bryan Barberena    win        185.0       3
#
#       Venue        Date                          Location     Billing  \
# 0  UFC Apex  2024-03-16  Las Vegas, Nevada, United States  Main Event
# 2  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 3  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 4  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 5  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
#
#                             Event Name        Referee       Description  \
# 0  UFC Fight Night: Tuivasa vs. Tybura      Herb Dean  Rear Naked Choke
# 2  UFC Fight Night: Tuivasa vs. Tybura     Mark Smith             Split
# 3  UFC Fight Night: Tuivasa vs. Tybura  Chris Tognoni             Split
# 4  UFC Fight Night: Tuivasa vs. Tybura     Mark Smith  Rear Naked Choke
# 5  UFC Fight Night: Tuivasa vs. Tybura      Herb Dean  Rear Naked Choke
#
#        Method  Finish  Odds A Title A  Weight A  Age A  Height A  Reach A  \
# 0  Submission       1    -105     NaN     247.0     38     191.0    198.0
# 2    Decision       0     500     NaN     206.0     40     191.0    203.0
# 3    Decision       0     165     NaN     145.0     26     170.0    180.0
# 4  Submission       1    -230     NaN     135.5     32     180.0    183.0
# 5  Submission       2    -250     NaN     185.5     36     185.0    197.0
#
#    KO win A  KO loss A  Sub win A  Sub loss A  Dec win A  Dec loss A  Draws A  \
# 0         9          5          6           0          9           3        0
# 2        12          5          8           3          6           9        0
# 3         3          0          4           0          3           1        0
# 4         2          1          2           1          4           1        0
# 5         6          4         27           8          2           5        0
#
#    UFC win A  UFC loss A  UFC draws A  Nationality A  Nick A  \
# 0         11           7            0         Poland   Tybur
# 2         14          12            0  United States     OSP
# 3          3           1            0  United States  CeeRod
# 4          6           3            0  United States     NaN
# 5         10           9            0  United States     GM3
#
#           Odds cat A  Odds B Title B  Weight B  Age B  Height B  Reach B  \
# 0          Near Even    -115     NaN     265.5     31     188.0    191.0
# 2     Heavy Underdog    -700     NaN     205.0     31     196.0    211.0
# 3    Slight Underdog    -200     NaN     145.5     27     170.0    180.0
# 4  Moderate Favorite     190     NaN     136.0     32     170.0    168.0
# 5  Moderate Favorite     200     NaN     186.0     34     183.0    183.0
#
#    KO win B  KO loss B  Sub win B  Sub loss B  Dec win B  Dec loss B  Draws B  \
# 0        13          3          0           2          1           1        0
# 2         8          2          1           1          3           1        0
# 3         4          0          2           0          0           0        0
# 4         3          1          0           2         13           4        0
# 5        11          2          2           3          5           6        0
#
#    UFC win B  UFC loss B  UFC draws B  Nationality B              Nick B  \
# 0          8           6            0      Australia             Bam Bam
# 2          6           4            0  United States     American Savage
# 3          1           0            0  United States  The MidWest Choppa
# 4          5           4            0         Sweden              Banzai
# 5          9           9            0  United States             Bam Bam
#
#           Odds cat B  Height Diff  Reach Diff  Age Diff Height Comparison  \
# 0          Near Even          3.0         7.0         7            Taller
# 2      Huge Favorite         -5.0        -8.0         9           Smaller
# 3  Moderate Favorite          0.0         0.0        -1              Same
# 4    Slight Underdog         10.0        15.0         0            Taller
# 5  Moderate Underdog          2.0        14.0         2            Taller
#
#   Reach Comparison Age Comparison  Tolerance
# 0           Longer          Older        1.0
# 2          Shorter          Older        1.0
# 3             Same        Younger        1.0
# 4           Longer           Same        1.0
# 5           Longer          Older        1.0

# %%
df_win["Tolerance"].value_counts()
# Out:
# Tolerance
# 1.0    6704
# 0.0     453
# Name: count, dtype: int64

# %%
df_win["Weight Miss A"] = ((df_win["Weightclass"] + df_win["Tolerance"]) < df_win["Weight A"])
df_win["Weight Miss B"] = ((df_win["Weightclass"] + df_win["Tolerance"]) < df_win["Weight B"])
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\379662204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win["Weight Miss A"] = ((df_win["Weightclass"] + df_win["Tolerance"]) < df_win["Weight A"])
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\379662204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win["Weight Miss B"] = ((df_win["Weightclass"] + df_win["Tolerance"]) < df_win["Weight B"])

# %%
df_win.iloc[20:50]
# Out:
#                  Fighter A              Fighter B Result  Weightclass  Rounds  \
# 21          Kyler Phillips           Pedro Munhoz    win        135.0       3
# 22            Philipe Lins           Ion Cutelaba    win        205.0       3
# 23          Michel Pereira    Michał Oleksiejczuk    win        185.0       3
# 24       Robelis Despaigne          Josh Parisian    win        265.0       3
# 25            Asu Almabaev             CJ Vergara    win        125.0       3
# 26             Joanne Wood           Maryna Moroz    win        125.0       3
# 27   Jairzinho Rozenstruik          Shamil Gaziev    win        265.0       5
# 28           Vitor Petrino            Tyson Pedro    win        205.0       3
# 29         Muhammad Mokaev             Alex Perez    win        125.0       3
# 30       Umar Nurmagomedov        Bekzat Almakhan    win        135.0       3
# 31             Steve Erceg           Matt Schnell    win        125.0       3
# 32             Eryk Anders          Jamie Pickett    win        185.0       3
# 33       Vinicius Oliveira          Benardo Sopaj    win        135.0       3
# 34          Aiemann Zahabi         Javid Basharat    win        135.0       3
# 35  Christian Leroy Duncan        Claudio Ribeiro    win        185.0       3
# 36           Ľudovít Klein          AJ Cunningham    win        155.0       3
# 37          Loik Radzhabov          A. Al-Selwady    win        155.0       3
# 38          Brandon Royval         Brandon Moreno    win        125.0       5
# 39            Brian Ortega         Yair Rodriguez    win        145.0       5
# 40        Daniel Zellhuber        Francisco Prado    win        155.0       3
# 41         Yazmin Jauregui             Sam Hughes    win        115.0       3
# 42           Manuel Torres           Chris Duncan    win        155.0       3
# 43          Raoni Barcelos      Cristian Quiñonez    win        135.0       3
# 44           Jesus Aguilar        Mateus Mendonça    win        125.0       3
# 45           Edgar Cháirez         Daniel Lacerda    win        125.0       3
# 46              Fares Ziam        Claudio Puelles    win        155.0       3
# 47       Ronaldo Rodríguez           Denys Bondar    win        125.0       3
# 48       Felipe dos Santos      Victor Altamirano    win        125.0       3
# 49         Muhammad Naimov             Erik Silva    win        145.0       3
# 50            Ilia Topuria  Alexander Volkanovski    win        145.0       5
#
#             Venue        Date                            Location     Billing  \
# 21  Kaseya Center  2024-03-09       Miami, Florida, United States      Prelim
# 22  Kaseya Center  2024-03-09       Miami, Florida, United States      Prelim
# 23  Kaseya Center  2024-03-09       Miami, Florida, United States      Prelim
# 24  Kaseya Center  2024-03-09       Miami, Florida, United States      Prelim
# 25  Kaseya Center  2024-03-09       Miami, Florida, United States      Prelim
# 26  Kaseya Center  2024-03-09       Miami, Florida, United States      Prelim
# 27       UFC Apex  2024-03-02    Las Vegas, Nevada, United States  Main Event
# 28       UFC Apex  2024-03-02    Las Vegas, Nevada, United States     Co-Main
# 29       UFC Apex  2024-03-02    Las Vegas, Nevada, United States   Main Card
# 30       UFC Apex  2024-03-02    Las Vegas, Nevada, United States   Main Card
# 31       UFC Apex  2024-03-02    Las Vegas, Nevada, United States   Main Card
# 32       UFC Apex  2024-03-02    Las Vegas, Nevada, United States      Prelim
# 33       UFC Apex  2024-03-02    Las Vegas, Nevada, United States      Prelim
# 34       UFC Apex  2024-03-02    Las Vegas, Nevada, United States      Prelim
# 35       UFC Apex  2024-03-02    Las Vegas, Nevada, United States      Prelim
# 36       UFC Apex  2024-03-02    Las Vegas, Nevada, United States      Prelim
# 37       UFC Apex  2024-03-02    Las Vegas, Nevada, United States      Prelim
# 38     Arena CDMX  2024-02-24                 Mexico City, Mexico  Main Event
# 39     Arena CDMX  2024-02-24                 Mexico City, Mexico     Co-Main
# 40     Arena CDMX  2024-02-24                 Mexico City, Mexico   Main Card
# 41     Arena CDMX  2024-02-24                 Mexico City, Mexico   Main Card
# 42     Arena CDMX  2024-02-24                 Mexico City, Mexico   Main Card
# 43     Arena CDMX  2024-02-24                 Mexico City, Mexico      Prelim
# 44     Arena CDMX  2024-02-24                 Mexico City, Mexico      Prelim
# 45     Arena CDMX  2024-02-24                 Mexico City, Mexico      Prelim
# 46     Arena CDMX  2024-02-24                 Mexico City, Mexico      Prelim
# 47     Arena CDMX  2024-02-24                 Mexico City, Mexico      Prelim
# 48     Arena CDMX  2024-02-24                 Mexico City, Mexico      Prelim
# 49     Arena CDMX  2024-02-24                 Mexico City, Mexico      Prelim
# 50   Honda Center  2024-02-17  Anaheim, California, United States  Main Event
#
#                                  Event Name          Referee  \
# 21             UFC 299: O'Malley vs. Vera 2   Keith Peterson
# 22             UFC 299: O'Malley vs. Vera 2     Mike Beltran
# 23             UFC 299: O'Malley vs. Vera 2  Dan Miragliotta
# 24             UFC 299: O'Malley vs. Vera 2     Andrew Glenn
# 25             UFC 299: O'Malley vs. Vera 2   Keith Peterson
# 26             UFC 299: O'Malley vs. Vera 2     Mike Beltran
# 27  UFC Fight Night: Rozenstruik vs. Gaziev     Marc Goddard
# 28  UFC Fight Night: Rozenstruik vs. Gaziev       Mark Smith
# 29  UFC Fight Night: Rozenstruik vs. Gaziev   Keith Peterson
# 30  UFC Fight Night: Rozenstruik vs. Gaziev     Marc Goddard
# 31  UFC Fight Night: Rozenstruik vs. Gaziev    Chris Tognoni
# 32  UFC Fight Night: Rozenstruik vs. Gaziev       Mark Smith
# 33  UFC Fight Night: Rozenstruik vs. Gaziev   Keith Peterson
# 34  UFC Fight Night: Rozenstruik vs. Gaziev    Chris Tognoni
# 35  UFC Fight Night: Rozenstruik vs. Gaziev       Mark Smith
# 36  UFC Fight Night: Rozenstruik vs. Gaziev   Keith Peterson
# 37  UFC Fight Night: Rozenstruik vs. Gaziev    Chris Tognoni
# 38     UFC Fight Night: Moreno vs. Royval 2        Herb Dean
# 39     UFC Fight Night: Moreno vs. Royval 2     Marc Goddard
# 40     UFC Fight Night: Moreno vs. Royval 2     Mike Beltran
# 41     UFC Fight Night: Moreno vs. Royval 2        Herb Dean
# 42     UFC Fight Night: Moreno vs. Royval 2     Mike Beltran
# 43     UFC Fight Night: Moreno vs. Royval 2    Bladimir Puga
# 44     UFC Fight Night: Moreno vs. Royval 2   Fernando Salas
# 45     UFC Fight Night: Moreno vs. Royval 2     Marc Goddard
# 46     UFC Fight Night: Moreno vs. Royval 2        Herb Dean
# 47     UFC Fight Night: Moreno vs. Royval 2     Mike Beltran
# 48     UFC Fight Night: Moreno vs. Royval 2    Bladimir Puga
# 49     UFC Fight Night: Moreno vs. Royval 2   Fernando Salas
# 50         UFC 298: Volkanovski vs. Topuria     Jason Herzog
#
#                           Description      Method  Finish  Odds A     Title A  \
# 21                          Unanimous    Decision       0    -220         NaN
# 22                          Unanimous    Decision       0     120         NaN
# 23                   Rear Naked Choke  Submission       1    -150         NaN
# 24                      Counter Right      KO/TKO       1    -400         NaN
# 25                          Unanimous    Decision       0    -600         NaN
# 26                              Split    Decision       0     180         NaN
# 27                         Retirement      KO/TKO       4     150         NaN
# 28                          Unanimous    Decision       0    -325         NaN
# 29                          Unanimous    Decision       0    -350         NaN
# 30                          Unanimous    Decision       0   -1400         NaN
# 31  Straight Right to Left Hook Combo      KO/TKO       2    -440         NaN
# 32                          Unanimous    Decision       0    -520         NaN
# 33                        Flying Knee      KO/TKO       3    -135         NaN
# 34                          Unanimous    Decision       0     575         NaN
# 35                   Ground and Pound      KO/TKO       2    -325         NaN
# 36                 Front Kick to Body      KO/TKO       1    -900         NaN
# 37       Right Hook to Ground Strikes      KO/TKO       3     150         NaN
# 38                              Split    Decision       0     240         NaN
# 39                 Arm Triangle Choke  Submission       3     125         NaN
# 40                          Unanimous    Decision       0    -275         NaN
# 41                          Unanimous    Decision       0    -600         NaN
# 42                   Rear Naked Choke  Submission       1    -190         NaN
# 43                   Rear Naked Choke  Submission       3    -170         NaN
# 44                              Split    Decision       0     105         NaN
# 45                     Triangle Choke  Submission       1    -500         NaN
# 46                              Split    Decision       0    -210         NaN
# 47                   Rear Naked Choke  Submission       2    -120         NaN
# 48                              Split    Decision       0    -300         NaN
# 49                         Leg Injury      KO/TKO       1    -600         NaN
# 50                         Right Hook      KO/TKO       2     115  Challenger
#
#     Weight A  Age A  Height A  Reach A  KO win A  KO loss A  Sub win A  \
# 21     135.0     28     173.0    183.0         5          0          2
# 22     206.0     38     188.0    198.0         9          4          4
# 23     186.0     30     186.0    185.0        11          2          7
# 24     261.0     35     201.0    221.0         4          0          0
# 25     126.0     30     163.0    165.0         3          1          9
# 26     125.0     38     168.0    166.0         5          0          1
# 27     257.0     35     188.0    198.0        12          2          0
# 28     205.5     26     188.0    197.0         7          0          1
# 29     126.0     23     170.0    178.0         2          0          6
# 30     136.0     28     172.0    175.0         2          0          7
# 31     126.0     28     173.0    174.0         1          0          6
# 32     185.5     36     185.0    191.0         9          1          1
# 33     135.5     28     175.0    179.0        15          3          2
# 34     135.5     36     173.0    174.0         6          1          2
# 35     186.0     28     188.0    201.0         7          0          1
# 36     156.0     29     170.0    184.0         8          1          8
# 37     155.5     33     180.0    175.0         7          1          5
# 38     126.0     31     175.0    179.0         4          1          9
# 39     146.0     33     173.0    175.0         3          2          7
# 40     156.0     24     185.0    196.0         7          0          3
# 41     115.0     24     160.0    163.0         7          1          0
# 42     155.0     28     178.0    185.0         7          0          6
# 43     135.0     36     173.0    183.0         8          1          2
# 44     126.0     27     163.0    157.0         1          0          6
# 45     131.0     28     170.0    183.0         4          0          6
# 46     156.0     26     185.0    191.0         5          0          4
# 47     126.0     24     168.0    165.0         8          0          4
# 48     124.0     23     170.0    178.0         2          0          3
# 49     146.0     29     175.0    178.0         5          0          2
# 50     144.5     27     170.0    175.0         4          0          8
#
#     Sub loss A  Dec win A  Dec loss A  Draws A  UFC win A  UFC loss A  \
# 21           0          4           2        0          5           1
# 22           0          4           1        0          3           2
# 23           1         11           8        0          7           2
# 24           0          0           0        0          0           0
# 25           0          6           1        0          1           0
# 26           5         10           3        0          8           8
# 27           1          1           2        0          7           5
# 28           0          2           0        0          3           0
# 29           0          3           0        0          5           0
# 30           0          7           0        0          4           0
# 31           0          4           1        0          2           0
# 32           1          5           6        0          7           8
# 33           0          2           0        0          0           0
# 34           0          2           1        0          4           2
# 35           0          1           1        0          2           1
# 36           2          4           1        1          4           2
# 37           0          5           4        1          1           1
# 38           1          2           5        0          5           3
# 39           0          5           1        0          7           3
# 40           0          4           1        0          2           1
# 41           0          3           0        0          2           1
# 42           2          1           0        0          2           0
# 43           1          7           3        0          6           4
# 44           2          2           0        0          1           1
# 45           2          0           3        0          0           1
# 46           3          5           1        0          4           2
# 47           0          3           2        0          0           0
# 48           0          2           1        0          0           1
# 49           0          3           2        0          2           0
# 50           0          2           0        0          6           0
#
#     UFC draws A  Nationality A                       Nick A  \
# 21            0  United States                       Matrix
# 22            0         Brazil                      Monstro
# 23            0         Brazil                    Demolidor
# 24            0           Cuba                  The Bad Boy
# 25            0     Kazakhstan                    Zulfikhar
# 26            0       Scotland                         JoJo
# 27            0       Suriname                     Bigi Boy
# 28            0         Brazil  Icao / Merciless / Cabuloso
# 29            0        England                 The Punisher
# 30            0         Russia                          NaN
# 31            0      Australia                    Astro Boy
# 32            0  United States                       Ya Boi
# 33            0         Brazil                      Lok Dog
# 34            0         Canada                          NaN
# 35            0        England                          NaN
# 36            1       Slovakia                Mr. Highlight
# 37            0     Tajikistan               The Tajik Tank
# 38            0  United States                     Raw Dawg
# 39            0  United States                       T-City
# 40            0         Mexico                   Golden Boy
# 41            0         Mexico                          NaN
# 42            0         Mexico                      El Loco
# 43            0         Brazil                          NaN
# 44            0         Mexico                          NaN
# 45            0         Mexico                 Puro Chicali
# 46            0         France                 Smile Killer
# 47            0         Mexico                     Lazy Boy
# 48            0         Brazil                  Lipe Detona
# 49            0     Tajikistan                      Hillman
# 50            0          Spain                   El Matador
#
#            Odds cat A  Odds B   Title B  Weight B  Age B  Height B  Reach B  \
# 21  Moderate Favorite     180       NaN     135.0     37     168.0    165.0
# 22          Near Even    -140       NaN     205.0     30     185.0    191.0
# 23    Slight Favorite     125       NaN     185.0     29     184.0    188.0
# 24     Heavy Favorite     310       NaN     266.0     34     193.0    201.0
# 25      Huge Favorite     425       NaN     127.0     32     168.0    173.0
# 26    Slight Underdog    -225       NaN     126.0     32     170.0    170.0
# 27    Slight Underdog    -175       NaN     261.0     34     193.0    199.0
# 28  Moderate Favorite     250       NaN     205.5     32     191.0    201.0
# 29  Moderate Favorite     280       NaN     125.5     31     168.0    166.0
# 30      Huge Favorite     775       NaN     136.0     26     170.0    173.0
# 31     Heavy Favorite     340       NaN     126.0     34     173.0    178.0
# 32     Heavy Favorite     390       NaN     186.0     35     188.0    203.0
# 33    Slight Favorite     115       NaN     135.5     23     168.0    168.0
# 34     Heavy Underdog    -900       NaN     136.0     28     175.0    175.0
# 35  Moderate Favorite     260       NaN     185.5     31     185.0    196.0
# 36      Huge Favorite     600       NaN     155.5     29     178.0    180.0
# 37    Slight Underdog    -185       NaN     156.0     28     173.0    175.0
# 38  Moderate Underdog    -300       NaN     126.0     30     170.0    178.0
# 39    Slight Underdog    -150       NaN     146.0     31     180.0    180.0
# 40  Moderate Favorite     230       NaN     156.0     21     180.0    175.0
# 41      Huge Favorite     425       NaN     115.0     31     165.0    164.0
# 42    Slight Favorite     160       NaN     156.0     30     178.0    182.0
# 43    Slight Favorite     145       NaN     135.0     27     173.0    178.0
# 44          Near Even    -125       NaN     126.0     25     168.0    182.0
# 45     Heavy Favorite     370       NaN     127.0     27     168.0    178.0
# 46  Moderate Favorite     170       NaN     156.0     27     178.0    183.0
# 47          Near Even     100       NaN     126.0     31     168.0    175.0
# 48  Moderate Favorite     240       NaN     125.0     33     173.0    178.0
# 49      Huge Favorite     425       NaN     146.0     36     175.0    180.0
# 50          Near Even    -140  Champion     144.5     35     168.0    182.0
#
#     KO win B  KO loss B  Sub win B  Sub loss B  Dec win B  Dec loss B  \
# 21         5          0          8           0          7           8
# 22        13          4          2           4          2           1
# 23        14          1          1           4          4           1
# 24        11          2          2           2          2           3
# 25         7          0          0           2          5           2
# 26         1          0          6           1          4           4
# 27         8          0          3           0          1           0
# 28         5          1          5           1          0           2
# 29         5          1          7           5         12           1
# 30         9          0          1           1          1           0
# 31         3          4          9           2          4           1
# 32         9          2          0           4          4           4
# 33         7          0          3           0          1           2
# 34         5          0          6           0          3           0
# 35        11          2          0           1          0           1
# 36         4          1          4           0          3           2
# 37         8          3          2           0          5           0
# 38         5          0         11           0          5           7
# 39         8          3          5           0          6           1
# 40         6          0          6           0          0           1
# 41         2          1          3           1          3           3
# 42         7          1          1           0          3           0
# 43        10          2          3           2          5           0
# 44         3          1          4           0          3           1
# 45         5          4          6           1          0           0
# 46         2          2          7           0          3           1
# 47         4          1         10           1          0           2
# 48         2          0          4           1          6           2
# 49         3          0          4           2          2           0
# 50        13          2          3           0         10           1
#
#     Draws B  UFC win B  UFC loss B  UFC draws B  Nationality B  \
# 21        0         10           8            0         Brazil
# 22        1          6           8            1        Moldova
# 23        0          7           4            0         Poland
# 24        0          2           4            0  United States
# 25        1          3           2            0  United States
# 26        0          6           5            0        Ukraine
# 27        0          1           0            0        Bahrain
# 28        0          6           4            0      Australia
# 29        0          6           3            0  United States
# 30        0          0           0            0     Kazakhstan
# 31        0          6           5            0  United States
# 32        0          2           6            0  United States
# 33        0          0           0            0        Albania
# 34        0          3           0            0        England
# 35        0          1           2            0         Brazil
# 36        0          0           0            0  United States
# 37        0          0           0            0  United States
# 38        2          9           4            2         Mexico
# 39        0         10           3            0         Mexico
# 40        0          1           1            0      Argentina
# 41        0          3           4            0  United States
# 42        0          2           0            0       Scotland
# 43        0          1           1            0         Mexico
# 44        0          0           2            0         Brazil
# 45        0          0           4            0         Brazil
# 46        0          5           2            0           Peru
# 47        0          0           2            0        Ukraine
# 48        0          2           2            0  United States
# 49        0          0           1            0      Venezuela
# 50        0         13           2            0      Australia
#
#                 Nick B         Odds cat B  Height Diff  Reach Diff  Age Diff  \
# 21  The Young Punisher    Slight Underdog          5.0        18.0        -9
# 22            The Hulk    Slight Favorite          3.0         7.0         8
# 23              Hussar    Slight Underdog          2.0        -3.0         1
# 24                 NaN  Moderate Underdog          8.0        20.0         1
# 25                 NaN     Heavy Underdog         -5.0        -8.0        -2
# 26       The Iron Lady  Moderate Favorite         -2.0        -4.0         6
# 27                 NaN    Slight Favorite         -5.0        -1.0         1
# 28                 NaN  Moderate Underdog         -3.0        -4.0        -6
# 29                 NaN  Moderate Underdog          2.0        12.0        -8
# 30                 NaN      Huge Underdog          2.0         2.0         2
# 31              Danger  Moderate Underdog          0.0        -4.0        -6
# 32       The Nightwolf  Moderate Underdog         -3.0       -12.0         1
# 33       The Lion King          Near Even          7.0        11.0         5
# 34    The Snow Leopard      Huge Favorite         -2.0        -1.0         8
# 35                 NaN  Moderate Underdog          3.0         5.0        -3
# 36          The Savage      Huge Underdog         -8.0         4.0         0
# 37                 NaN    Slight Favorite          7.0         0.0         5
# 38   The Assassin Baby  Moderate Favorite          5.0         1.0         1
# 39          El Pantera    Slight Favorite         -7.0        -5.0         2
# 40                 NaN  Moderate Underdog          5.0        21.0         3
# 41             Sampage     Heavy Underdog         -5.0        -1.0        -7
# 42         The Problem    Slight Underdog          0.0         3.0        -2
# 43    El Nino Problema    Slight Underdog          0.0         5.0         9
# 44               Bocao    Slight Favorite         -5.0       -25.0         2
# 45               Miojo  Moderate Underdog          2.0         5.0         1
# 46      Prince of Peru    Slight Underdog          7.0         8.0        -1
# 47              Psycho          Near Even          0.0       -10.0        -7
# 48        El Magnifico  Moderate Underdog         -3.0         0.0       -10
# 49            The King     Heavy Underdog          0.0        -2.0        -7
# 50           The Great    Slight Favorite          2.0        -7.0        -8
#
#    Height Comparison Reach Comparison Age Comparison  Tolerance  \
# 21            Taller           Longer        Younger        1.0
# 22            Taller           Longer          Older        1.0
# 23            Taller          Shorter          Older        1.0
# 24            Taller           Longer          Older        1.0
# 25           Smaller          Shorter        Younger        1.0
# 26           Smaller          Shorter          Older        1.0
# 27           Smaller          Shorter          Older        1.0
# 28           Smaller          Shorter        Younger        1.0
# 29            Taller           Longer        Younger        1.0
# 30            Taller           Longer          Older        1.0
# 31              Same          Shorter        Younger        1.0
# 32           Smaller          Shorter          Older        1.0
# 33            Taller           Longer          Older        1.0
# 34           Smaller          Shorter          Older        1.0
# 35            Taller           Longer        Younger        1.0
# 36           Smaller           Longer           Same        1.0
# 37            Taller             Same          Older        1.0
# 38            Taller           Longer          Older        1.0
# 39           Smaller          Shorter          Older        1.0
# 40            Taller           Longer          Older        1.0
# 41           Smaller          Shorter        Younger        1.0
# 42              Same           Longer        Younger        1.0
# 43              Same           Longer          Older        1.0
# 44           Smaller          Shorter          Older        1.0
# 45            Taller           Longer          Older        1.0
# 46            Taller           Longer        Younger        1.0
# 47              Same          Shorter        Younger        1.0
# 48           Smaller             Same        Younger        1.0
# 49              Same          Shorter        Younger        1.0
# 50            Taller          Shorter        Younger        0.0
#
#     Weight Miss A  Weight Miss B
# 21          False          False
# 22          False          False
# 23          False          False
# 24          False          False
# 25          False           True
# 26          False          False
# 27          False          False
# 28          False          False
# 29          False          False
# 30          False          False
# 31          False          False
# 32          False          False
# 33          False          False
# 34          False          False
# 35          False          False
# 36          False          False
# 37          False          False
# 38          False          False
# 39          False          False
# 40          False          False
# 41          False          False
# 42          False          False
# 43          False          False
# 44          False          False
# 45           True           True
# 46          False          False
# 47          False          False
# 48          False          False
# 49          False          False
# 50          False          False

# %%
df_win.groupby(["Weight Miss A", "Weight Miss B"])["Result"].count().reset_index()
# Out:
#    Weight Miss A  Weight Miss B  Result
# 0          False          False    6883
# 1          False           True     149
# 2           True          False     118
# 3           True           True       7

# %% [markdown]
# We can see that there are 149 cases where fighter that didnt make weight lost and 118 cases where fighter that didnt make weight won.
#
# There is also 7 cases where both fighters didnt make weight.
#
# This indicates that fighters who miss weight are more likely to lose the fight. This might be caused by some underlying illness or the weight cut difficulties themselves.

# %%
sizes = [149, 118]
labels = ['Overweight Loss', 'Overweight Win']
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
plt.title('')
plt.show()

# %% [markdown]
# ### 3. How do past results of fighters affect result?

# %%
df_win['Win Comparison'] = np.where(df_win['UFC win A'] > df_win['UFC win B'], 'More', 
                             np.where(df_win['UFC win A'] < df_win['UFC win B'], 'Less', 'Even'))
df_win['Loss Comparison'] = np.where(df_win['UFC loss A'] > df_win['UFC loss B'], 'More', 
                             np.where(df_win['UFC loss A'] < df_win['UFC loss B'], 'Less', 'Even'))
df_win['Draw Comparison'] = np.where(df_win['UFC draws A'] > df_win['UFC draws B'], 'More', 
                             np.where(df_win['UFC draws A'] < df_win['UFC draws B'], 'Less', 'Even'))
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\3354151202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win['Win Comparison'] = np.where(df_win['UFC win A'] > df_win['UFC win B'], 'More',
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\3354151202.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win['Loss Comparison'] = np.where(df_win['UFC loss A'] > df_win['UFC loss B'], 'More',
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\3354151202.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win['Draw Comparison'] = np.where(df_win['UFC draws A'] > df_win['UFC draws B'], 'More',

# %%
df_comp = df_win.groupby(["Win Comparison", 'Loss Comparison'])["Result"].count().reset_index().sort_values("Result", ascending=False)
df_comp
# Out:
#   Win Comparison Loss Comparison  Result
# 8           More            More    1929
# 4           Less            Less    1826
# 0           Even            Even     760
# 6           More            Even     657
# 1           Even            Less     471
# 7           More            Less     427
# 3           Less            Even     414
# 2           Even            More     387
# 5           Less            More     286

# %%
# Create a pivot table to prepare the data for heatmap and fill missing values with 0
pivot_table = df_comp.pivot_table(index="Win Comparison", columns="Loss Comparison", values="Result", fill_value=0)
pivot_table2 = df_comp.pivot_table(index="Win Comparison", columns="Loss Comparison", values="Result")

# %%
# Iterate through every column in the pivot table
for column_name, series in pivot_table.items():
    # Iterate through every index-value pair in the columns Series
    for index, cell_value in series.items():
        # Perform operations with each cell value
        if (cell_value + pivot_table.loc[column_name, index]) != 0:
            pivot_table2.loc[index, column_name] = cell_value / (cell_value + pivot_table.loc[column_name, index])
        else:
            pivot_table2.loc[index, column_name] = 0

# %%
sns.heatmap(data=pivot_table2, cmap="Blues", annot=True)
plt.ylabel('Wins Number')
plt.xlabel('Losses Number')
plt.title('Win percentage for each combination')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# From the heatmap above we can see that:
# 1. The fighter who has Even number of wins and Less losses as his opponent, is likely to win in 53% of fights.
# 2. The fighter who has More number of wins and Even losses as his opponent, is likely to win in 63% of fights.
# 3. The fighter who has More number of wins and Less losses as his opponent, is likely to win in 60% of fights.
#
# We can see that number of wins vs number of losses have an impact on the result of a match.
#
# We would expect that the results of points 2. and 3. would be different, because Less number of losses should be better than Even number of losses. This could be caused by the fact that some losses (up to a certain point) mean more experience.

# %% [markdown]
# ### 4. How did odds predict the fight?

# %%
df_win['Prediction'] = np.where(df_win['Odds A'] > df_win['Odds B'], 'Underdog', 
                             np.where(df_win['Odds A'] < df_win['Odds B'], 'Favorite', 'Even'))
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\3337512597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_win['Prediction'] = np.where(df_win['Odds A'] > df_win['Odds B'], 'Underdog',

# %%
df_pred = df_win.groupby(["Prediction"])["Result"].count().reset_index()
df_pred = df_pred.sort_values("Result", ascending=False)

# %%
plt.pie(df_pred['Result'], labels=df_pred['Prediction'], autopct='%1.1f%%')
plt.title('')
plt.show()

# %% [markdown]
# We can see that in 63.9% fights the Favorite won and in 32% of fights the Underdog won. There were few cases of even Odds as well.

# %% [markdown]
# We can go deeper and use odds categories we got from tapology scraping.

# %%
df_cats = df_win.groupby(["Odds cat A", "Odds cat B"])["Result"].count().reset_index()
df_cats
# Out:
#            Odds cat A         Odds cat B  Result
# 0                Even               Even     166
# 1      Heavy Favorite     Heavy Underdog     124
# 2      Heavy Favorite  Moderate Underdog     437
# 3      Heavy Underdog     Heavy Favorite      24
# 4      Heavy Underdog      Huge Favorite      32
# 5       Huge Favorite     Heavy Underdog     220
# 6       Huge Favorite      Huge Underdog     100
# 7       Huge Underdog      Huge Favorite      12
# 8   Moderate Favorite               Even       1
# 9   Moderate Favorite      Huge Underdog       1
# 10  Moderate Favorite  Moderate Underdog    1287
# 11  Moderate Favorite    Slight Underdog     690
# 12  Moderate Underdog     Heavy Favorite      79
# 13  Moderate Underdog  Moderate Favorite     454
# 14          Near Even          Near Even     490
# 15          Near Even    Slight Favorite     473
# 16    Slight Favorite          Near Even     528
# 17    Slight Favorite    Slight Favorite       2
# 18    Slight Favorite    Slight Underdog    1002
# 19    Slight Underdog  Moderate Favorite     356
# 20    Slight Underdog          Near Even       1
# 21    Slight Underdog    Slight Favorite     678

# %% [markdown]
# We have to create pivot table to plot a heatmap.

# %%
# Create a pivot table to prepare the data for heatmap and fill missing values with 0
pivot_table = df_cats.pivot_table(index="Odds cat A", columns="Odds cat B", values="Result", fill_value=0)
pivot_table2 = df_cats.pivot_table(index="Odds cat A", columns="Odds cat B", values="Result")

# %% [markdown]
# This piece of code fills the second pivot table with percentages calculated from the first table.

# %%
# Iterate through every column in the pivot table
for column_name, series in pivot_table.items():
    # Iterate through every index-value pair in the columns Series
    for index, cell_value in series.items():
        # Perform operations with each cell value
        if (cell_value + pivot_table.loc[column_name, index]) != 0:
            pivot_table2.loc[index, column_name] = cell_value / (cell_value + pivot_table.loc[column_name, index])
        else:
            pivot_table2.loc[index, column_name] = 0

# %%
pivot_table2
# Out:
# Odds cat B         Even  Heavy Favorite  Heavy Underdog  Huge Favorite  \
# Odds cat A
# Even                0.5        0.000000        0.000000       0.000000
# Heavy Favorite      0.0        0.000000        0.837838       0.000000
# Heavy Underdog      0.0        0.162162        0.000000       0.126984
# Huge Favorite       0.0        0.000000        0.873016       0.000000
# Huge Underdog       0.0        0.000000        0.000000       0.107143
# Moderate Favorite   1.0        0.000000        0.000000       0.000000
# Moderate Underdog   0.0        0.153101        0.000000       0.000000
# Near Even           0.0        0.000000        0.000000       0.000000
# Slight Favorite     0.0        0.000000        0.000000       0.000000
# Slight Underdog     0.0        0.000000        0.000000       0.000000
#
# Odds cat B         Huge Underdog  Moderate Favorite  Moderate Underdog  \
# Odds cat A
# Even                    0.000000           0.000000           0.000000
# Heavy Favorite          0.000000           0.000000           0.846899
# Heavy Underdog          0.000000           0.000000           0.000000
# Huge Favorite           0.892857           0.000000           0.000000
# Huge Underdog           0.000000           0.000000           0.000000
# Moderate Favorite       1.000000           0.000000           0.739230
# Moderate Underdog       0.000000           0.260770           0.000000
# Near Even               0.000000           0.000000           0.000000
# Slight Favorite         0.000000           0.000000           0.000000
# Slight Underdog         0.000000           0.340344           0.000000
#
# Odds cat B         Near Even  Slight Favorite  Slight Underdog
# Odds cat A
# Even                0.000000         0.000000         0.000000
# Heavy Favorite      0.000000         0.000000         0.000000
# Heavy Underdog      0.000000         0.000000         0.000000
# Huge Favorite       0.000000         0.000000         0.000000
# Huge Underdog       0.000000         0.000000         0.000000
# Moderate Favorite   0.000000         0.000000         0.659656
# Moderate Underdog   0.000000         0.000000         0.000000
# Near Even           0.500000         0.472527         0.000000
# Slight Favorite     0.527473         0.500000         0.596429
# Slight Underdog     1.000000         0.403571         0.000000

# %%
pivot_table
# Out:
# Odds cat B          Even  Heavy Favorite  Heavy Underdog  Huge Favorite  \
# Odds cat A
# Even               166.0             0.0             0.0            0.0
# Heavy Favorite       0.0             0.0           124.0            0.0
# Heavy Underdog       0.0            24.0             0.0           32.0
# Huge Favorite        0.0             0.0           220.0            0.0
# Huge Underdog        0.0             0.0             0.0           12.0
# Moderate Favorite    1.0             0.0             0.0            0.0
# Moderate Underdog    0.0            79.0             0.0            0.0
# Near Even            0.0             0.0             0.0            0.0
# Slight Favorite      0.0             0.0             0.0            0.0
# Slight Underdog      0.0             0.0             0.0            0.0
#
# Odds cat B         Huge Underdog  Moderate Favorite  Moderate Underdog  \
# Odds cat A
# Even                         0.0                0.0                0.0
# Heavy Favorite               0.0                0.0              437.0
# Heavy Underdog               0.0                0.0                0.0
# Huge Favorite              100.0                0.0                0.0
# Huge Underdog                0.0                0.0                0.0
# Moderate Favorite            1.0                0.0             1287.0
# Moderate Underdog            0.0              454.0                0.0
# Near Even                    0.0                0.0                0.0
# Slight Favorite              0.0                0.0                0.0
# Slight Underdog              0.0              356.0                0.0
#
# Odds cat B         Near Even  Slight Favorite  Slight Underdog
# Odds cat A
# Even                     0.0              0.0              0.0
# Heavy Favorite           0.0              0.0              0.0
# Heavy Underdog           0.0              0.0              0.0
# Huge Favorite            0.0              0.0              0.0
# Huge Underdog            0.0              0.0              0.0
# Moderate Favorite        0.0              0.0            690.0
# Moderate Underdog        0.0              0.0              0.0
# Near Even              490.0            473.0              0.0
# Slight Favorite        528.0              2.0           1002.0
# Slight Underdog          1.0            678.0              0.0

# %%
sns.heatmap(data=pivot_table2, cmap="Blues", annot=True)
plt.xlabel('Loser')
plt.ylabel('Winner')
plt.title('Win percentage for each category')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# From the heatmap we can see one very interesting insights.
#
# 1. "Heavy Favourite" wins less percentage of matches against "Heavy Underdog", than against "Moderate Underdog" which shouldnt be the case if odds were done correctly.
# 2. There are three values of 100% winrate. In all three cases it is cause by only one record, therefore it is not interesting.
# 3. All the other values make sense and are predicted correctly.

# %% [markdown]
# ### 5. Do external conditions like referee, arena, weight category or rounds affect how the fight ends?

# %%
df = ufc_data
df.shape
# Out:
# (7294, 52)

# %%
method_perc = df["Method"].value_counts(normalize=True)
method_perc.plot(kind='bar')
plt.xlabel('Method')
plt.ylabel('Percentage')
plt.title('Barplot of Method Percentage')
plt.xticks(rotation=0)
plt.show()

# %%
method_perc
# Out:
# Method
# Decision      0.468604
# KO/TKO        0.324787
# Submission    0.195092
# No Contest    0.011516
# Name: proportion, dtype: float64

# %% [markdown]
# We can see that approx. 47% of fights end by decision, 32% by KO/TKO, 20% by submission and 1% by No Contest.
#
# Lets check if other characteristics have impact on this.

# %% [markdown]
# #### Referee effect on a method of finish.

# %% [markdown]
# First we select only referees with over 100 fights judged.

# %%
ref_count = df.groupby(["Referee"])["Result"].count().reset_index()
ref_count = ref_count[ref_count["Result"] >= 100]
ref_count.sort_values("Result", ascending=False)
# Out:
#               Referee  Result
# 66          Herb Dean    1092
# 32    Dan Miragliotta     462
# 125      Marc Goddard     456
# 91      John McCarthy     430
# 131    Mario Yamasaki     370
# 137        Mark Smith     370
# 29      Chris Tognoni     355
# 105    Keith Peterson     338
# 73       Jason Herzog     329
# 208      Yves Lavigne     265
# 182  Steve Mazzagatti     202
# 119      Leon Roberts     186
# 100    Josh Rosenthal     121
# 145      Mike Beltran     119
# 108   Kevin MacDonald     100

# %% [markdown]
# We have selected 15 referees for further inspection.

# %%
ref_df = df[df["Referee"].isin(ref_count["Referee"])]
ref_df.shape
# Out:
# (5195, 52)

# %% [markdown]
# Top 15 referees judged 5195 fights out of 7294 in our dataset.
#
# Now we perform the analysis.
#
# We count the results by "Referee" and "Method".

# %%
ref_method = ref_df.groupby(["Referee", "Method"])["Result"].count().reset_index()
ref_method
# Out:
#              Referee      Method  Result
# 0      Chris Tognoni    Decision     172
# 1      Chris Tognoni      KO/TKO     103
# 2      Chris Tognoni  No Contest       7
# 3      Chris Tognoni  Submission      73
# 4    Dan Miragliotta    Decision     193
# 5    Dan Miragliotta      KO/TKO     177
# 6    Dan Miragliotta  No Contest       5
# 7    Dan Miragliotta  Submission      87
# 8          Herb Dean    Decision     475
# 9          Herb Dean      KO/TKO     380
# 10         Herb Dean  No Contest      12
# 11         Herb Dean  Submission     225
# 12      Jason Herzog    Decision     157
# 13      Jason Herzog      KO/TKO     106
# 14      Jason Herzog  No Contest       4
# 15      Jason Herzog  Submission      62
# 16     John McCarthy    Decision     174
# 17     John McCarthy      KO/TKO     155
# 18     John McCarthy  No Contest      10
# 19     John McCarthy  Submission      91
# 20    Josh Rosenthal    Decision      60
# 21    Josh Rosenthal      KO/TKO      33
# 22    Josh Rosenthal  No Contest       2
# 23    Josh Rosenthal  Submission      26
# 24    Keith Peterson    Decision     175
# 25    Keith Peterson      KO/TKO     108
# 26    Keith Peterson  No Contest       4
# 27    Keith Peterson  Submission      51
# 28   Kevin MacDonald    Decision      46
# 29   Kevin MacDonald      KO/TKO      30
# 30   Kevin MacDonald  No Contest       2
# 31   Kevin MacDonald  Submission      22
# 32      Leon Roberts    Decision     100
# 33      Leon Roberts      KO/TKO      60
# 34      Leon Roberts  Submission      26
# 35      Marc Goddard    Decision     228
# 36      Marc Goddard      KO/TKO     143
# 37      Marc Goddard  No Contest       2
# 38      Marc Goddard  Submission      83
# 39    Mario Yamasaki    Decision     157
# 40    Mario Yamasaki      KO/TKO     123
# 41    Mario Yamasaki  No Contest       1
# 42    Mario Yamasaki  Submission      89
# 43        Mark Smith    Decision     185
# 44        Mark Smith      KO/TKO     126
# 45        Mark Smith  No Contest       2
# 46        Mark Smith  Submission      57
# 47      Mike Beltran    Decision      58
# 48      Mike Beltran      KO/TKO      37
# 49      Mike Beltran  No Contest       4
# 50      Mike Beltran  Submission      20
# 51  Steve Mazzagatti    Decision      77
# 52  Steve Mazzagatti      KO/TKO      69
# 53  Steve Mazzagatti  No Contest       2
# 54  Steve Mazzagatti  Submission      54
# 55      Yves Lavigne    Decision     130
# 56      Yves Lavigne      KO/TKO      79
# 57      Yves Lavigne  Submission      56

# %% [markdown]
# Lets create a pivot table and display it on a heatmap.

# %%
# Create a pivot table to prepare the data for heatmap and fill missing values with 0
pivot_table = ref_method.pivot_table(index="Referee", columns="Method", values="Result", fill_value=0)
pivot_table
# Out:
# Method            Decision  KO/TKO  No Contest  Submission
# Referee
# Chris Tognoni        172.0   103.0         7.0        73.0
# Dan Miragliotta      193.0   177.0         5.0        87.0
# Herb Dean            475.0   380.0        12.0       225.0
# Jason Herzog         157.0   106.0         4.0        62.0
# John McCarthy        174.0   155.0        10.0        91.0
# Josh Rosenthal        60.0    33.0         2.0        26.0
# Keith Peterson       175.0   108.0         4.0        51.0
# Kevin MacDonald       46.0    30.0         2.0        22.0
# Leon Roberts         100.0    60.0         0.0        26.0
# Marc Goddard         228.0   143.0         2.0        83.0
# Mario Yamasaki       157.0   123.0         1.0        89.0
# Mark Smith           185.0   126.0         2.0        57.0
# Mike Beltran          58.0    37.0         4.0        20.0
# Steve Mazzagatti      77.0    69.0         2.0        54.0
# Yves Lavigne         130.0    79.0         0.0        56.0

# %% [markdown]
# We calculate the percentage of methods for each Referee

# %%
pivot_table_perc = pivot_table.div(pivot_table.sum(axis=1), axis=0)
pivot_table_perc
# Out:
# Method            Decision    KO/TKO  No Contest  Submission
# Referee
# Chris Tognoni     0.484507  0.290141    0.019718    0.205634
# Dan Miragliotta   0.417749  0.383117    0.010823    0.188312
# Herb Dean         0.434982  0.347985    0.010989    0.206044
# Jason Herzog      0.477204  0.322188    0.012158    0.188450
# John McCarthy     0.404651  0.360465    0.023256    0.211628
# Josh Rosenthal    0.495868  0.272727    0.016529    0.214876
# Keith Peterson    0.517751  0.319527    0.011834    0.150888
# Kevin MacDonald   0.460000  0.300000    0.020000    0.220000
# Leon Roberts      0.537634  0.322581    0.000000    0.139785
# Marc Goddard      0.500000  0.313596    0.004386    0.182018
# Mario Yamasaki    0.424324  0.332432    0.002703    0.240541
# Mark Smith        0.500000  0.340541    0.005405    0.154054
# Mike Beltran      0.487395  0.310924    0.033613    0.168067
# Steve Mazzagatti  0.381188  0.341584    0.009901    0.267327
# Yves Lavigne      0.490566  0.298113    0.000000    0.211321

# %%
method_perc
# Out:
# Method
# Decision      0.468604
# KO/TKO        0.324787
# Submission    0.195092
# No Contest    0.011516
# Name: proportion, dtype: float64

# %%
# Define the numbers to subtract from each column
# Subtract each column by different numbers
for method, value in method_perc.items():
    if method in pivot_table_perc.columns:
        pivot_table_perc[method] = pivot_table_perc[method].sub(value)

# %%
pivot_table_perc
# Out:
# Method            Decision    KO/TKO  No Contest  Submission
# Referee
# Chris Tognoni     0.015903 -0.034647    0.008202    0.010542
# Dan Miragliotta  -0.050855  0.058329   -0.000694   -0.006780
# Herb Dean        -0.033623  0.023198   -0.000527    0.010952
# Jason Herzog      0.008599 -0.002599    0.000642   -0.006642
# John McCarthy    -0.063953  0.035678    0.011739    0.016536
# Josh Rosenthal    0.027263 -0.052060    0.005013    0.019784
# Keith Peterson    0.049147 -0.005261    0.000318   -0.044204
# Kevin MacDonald  -0.008604 -0.024787    0.008484    0.024908
# Leon Roberts      0.069030 -0.002207   -0.011516   -0.055307
# Marc Goddard      0.031396 -0.011191   -0.007130   -0.013074
# Mario Yamasaki   -0.044280  0.007645   -0.008814    0.045449
# Mark Smith        0.031396  0.015753   -0.006111   -0.041038
# Mike Beltran      0.018791 -0.013863    0.022097   -0.027025
# Steve Mazzagatti -0.087416  0.016797   -0.001615    0.072235
# Yves Lavigne      0.021962 -0.026674   -0.011516    0.016229

# %%
sns.heatmap(data=pivot_table_perc, cmap="vlag", annot=True)
plt.xlabel('Method')
plt.ylabel('Referee')
plt.title('Method distribution for each Referee')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# From the heatmap above, we can see that:
# 1. Dan Miragliotta has about 5.8% positive difference in KO/TKO finishes, which could mean he stops the fights more than he should.
# 2. John McCarthy has about 3.6% positive difference in KO/TKO finishes, which could mean he stops the fights more than he should.
# 3. Jack Rosenthal has about 5.2% negative difference in KO/TKO finishes, which could mean he stops the fights less than he should.
# 4. Chris Tognoni has about 3.5% negative difference in KO/TKO finishes, which could mean he stops the fights less than he should.
# 5. Jason Herzog shows the least deviation from the overall data, which could mean that he determines whether the fight should be stopped the best.
# 6. Mike Beltran has 2.2% positive difference in No Contest finishes, which in absolute numbers is almost triple, than what the norm is for the entire dataset.

# %% [markdown]
# Referee plays a role in mainly in KO/TKO finishes, because it is often up to him to determine, if the fighter is capable of defending himself or not.
#
# In Submission finishes, it is on the fighters themselves to stop the fight.

# %% [markdown]
# #### Venue effect on a method of finish.

# %% [markdown]
# Here we are mainly interested to find out how does one particular venue affect the method a fight ends.
#
# After Covid hit, the UFC started making some events in a small training arena called the UFC Apex. The octagon itself in this arena is smaller, and there is just about a hundred fans watching the fight (most of them are friends and family of the fighters).

# %%
pd.set_option('display.max_rows', None)
df["Venue"].value_counts()
# Out:
# Venue
# UFC APEX                                     764
# MGM Grand Garden Arena                       453
# T-Mobile Arena                               333
# UFC Apex                                     316
# Mandalay Bay Events Center                   292
# UFC Fight Island                             109
# Toyota Center                                108
# Prudential Center                             90
# Honda Center                                  89
# Madison Square Garden                         87
# TD Garden                                     84
# 02 Arena                                      82
# Bell Centre                                   81
# United Center                                 81
# American Airlines Center                      76
# Etihad Arena                                  74
# O2 Arena                                      72
# HSBC Arena                                    71
# VyStar Veterans Memorial Arena                70
# The Pearl at the Palms Casino Resort          65
# Singapore Indoor Stadium                      60
# Ericsson Globe Arena                          60
# Bridgestone Arena                             60
# Hard Rock Hotel and Casino                    57
# Rogers Arena                                  56
# Saitama Super Arena                           55
# Staples Center                                53
# Amway Center                                  52
# The Pearl at the Palms                        52
# Air Canada Centre                             49
# Arena Ciudad de Mexico                        47
# Ibirapuera Gymnasium                          46
# Pepsi Center                                  44
# Nationwide Arena                              41
# Jeunesse Arena                                40
# The Palms Casino Resort                       39
# Ginásio Nilson Nelson                         36
# HP Pavilion                                   35
# Frank Erwin Center                            34
# AT&T Center                                   34
# Patriot Center                                33
# Barclays Center                               32
# Mohegan Sun Arena                             32
# Target Center                                 32
# Gila River Arena                              28
# Palms Casino Resort                           28
# Boardwalk Hall                                27
# CotaiArena                                    27
# The Forum                                     26
# State Farm Arena                              25
# Auditório Ibirapuera                          25
# Ahoy Rotterdam                                25
# Scotiabank Arena                              25
# Amalie Arena                                  25
# Arena Jaragua                                 25
# Qudos Bank Arena                              25
# Moody Center                                  25
# Consol Energy Center                          24
# Barclaycard Arena                             24
# Scotiabank Saddledome                         24
# Bradley Center                                24
# SSE Hydro Arena                               24
# Rod Laver Arena                               24
# Wells Fargo Center                            24
# KeyArena                                      23
# Spectrum Center                               23
# Brisbane Entertainment Centre                 23
# Vivint Arena                                  23
# Revel Atlantic City                           23
# Accor Arena                                   23
# Rogers Place                                  22
# Estadio Jornalista Felippe Drummond           22
# MTS Centre                                    22
# U.S. Bank Arena                               22
# Allphones Arena                               22
# The Chelsea at The Cosmopolitan               22
# Vector Arena                                  21
# Philips Arena                                 21
# Manchester Evening News Arena                 21
# Acer Arena                                    21
# Sleep Train Arena                             19
# Arrowhead Pond                                18
# Seminole Hard Rock Hotel & Casino             18
# ARCO Arena                                    18
# Seminole Hard Rock Hotel and Casino           17
# Cox Pavilion                                  17
# Trump Taj Mahal                               15
# T-Mobile Center                               14
# Kaseya Center                                 14
# Ginásio do Ibirapuera                         14
# Footprint Center                              14
# Sprint Center                                 13
# KeyBank Center                                13
# Chesapeake Energy Arena                       13
# Nassau Coliseum                               13
# Golden 1 Center                               13
# The SSE Arena                                 13
# Fort Campbell                                 13
# Zagreb Arena                                  13
# Colisée Pepsi                                 13
# Monterrey Arena                               13
# Etihad Stadium                                13
# Arena at TD Place                             13
# SaveMart Center                               13
# Movistar Arena                                13
# Pechanga Arena                                13
# Sajik Arena                                   13
# Centro de Formacao Olimpica do Nordeste       13
# Moncton Events Centre                         13
# Antel Arena                                   13
# Pinnacle Bank Arena                           13
# INTRUST Bank Arena                            13
# BB&T Center                                   13
# CSKA Arena                                    13
# CenturyLink Arena                             13
# Santa Ana Star Center                         13
# Blue Cross Arena                              13
# RAC Arena                                     13
# The Theater at Virgin Hotels                  13
# Royal Arena                                   13
# du Arena                                      13
# Little Caesars Arena                          13
# Ted Constant Convocation Center               13
# Halifax Metro Centre                          12
# PNC Arena                                     12
# Capital One Arena                             12
# U.S. Airways Arena                            12
# SAP Center                                    12
# Jose Correa Gymnasium                         12
# Tele2 Arena                                   12
# Mexico City Arena                             12
# Rogers Centre                                 12
# The Prudential Center                         12
# Spark Arena                                   12
# Key Arena                                     12
# Chartway Arena                                12
# Gwinnett Center                               12
# New Orleans Convention Center                 12
# UBS Arena                                     12
# Phones4U Arena                                12
# Izod Center                                   12
# Bankers Life Fieldhouse                       12
# Miami-Dade Arena                              12
# Ginásio Paulo Sarasate                        12
# Arena CDMX                                    12
# Wembley Arena                                 12
# Rio de Janeiro, Brazil                        12
# Golden1 Center                                12
# Kraków Arena                                  12
# Wisconsin Entertainment and Sports Center     12
# Cadillac Arena                                12
# Arena da Baixada                              12
# Luna Park                                     12
# Olimpiyskiy Arena                             12
# Denny Sanford Premier Center                  12
# Vivint Smart Home Arena                       12
# Moda Center                                   12
# Adirondack Bank Center                        12
# Times Union Center                            12
# Perth Arena                                   12
# Talking Stick Arena                           12
# Lanxess Arena                                 12
# Olympic Training Center                       12
# Broomfield Event Center                       12
# Mercedes-Benz Arena                           12
# Adelaide Entertainment Center                 12
# BankAtlantic Center                           12
# Talking Stick Resort Arena                    12
# Canadian Tire Centre                          12
# SaskTel Centre                                12
# Adelaide Entertainment Centre                 12
# Valley View Casino Center                     12
# SM Mall of Asia Arena                         12
# Goiania Arena                                 12
# Smoothie King Center                          12
# Fort Hood                                     11
# Capital FM Arena                              11
# The National Indoor Arena                     11
# The Odeum Colorado                            11
# Bojangles Coliseum                            11
# FedEx Forum                                   11
# General Motors Place                          11
# Sommet Center                                 11
# Wachovia Center                               11
# Rose Garden                                   11
# Oracle Arena                                  11
# Conseco Fieldhouse                            11
# The Palace of Auburn Hills                    11
# KFC Yum! Center                               11
# Phillips Arena                                11
# Olympic Gymnastics Arena                      11
# Scotiabank Centre                             11
# Manchester Arena                              11
# Gigantinho Gymnasium                          11
# BOK Center                                    11
# 02 World Arena                                11
# Ergo Arena                                    11
# The Joint at the Hard Rock Hotel              11
# Tingley Colisuem                              11
# Park Theatre                                  11
# Scottrade Center                              11
# Mangueirinho Gymnasium                        11
# Nelio Dias Gymnasium                          11
# Echo Arena                                    11
# Yubileyny Sports Palace                       11
# Bon Secours Wellness Arena                    11
# Universiade Sports Centre                     11
# Goiana Arena                                  11
# Marvel Stadium                                11
# Ibirapuera Arena                              11
# Maracanazinho Gymnasium                       11
# Quicken Loans Arena                           10
# Gold Coast Convention Centre                  10
# PPG Paints Arena                              10
# The 02 Arena                                  10
# USF Sun Dome                                  10
# Crown Coliseum                                10
# Allstate Arena                                10
# Omaha Civic Auditorium                        10
# Cox Convention Center                         10
# 3Arena                                        10
# The O2 Dublin                                 10
# LG Arena / National Exhibition Centre         10
# Verizon Center                                10
# Marina Bay Sands                              10
# 1stBank Center                                10
# Baltimore Arena                               10
# O2 World Arena                                10
# Ginasio Poliesportivo Jose Correa             10
# Cross Insurance Center                        10
# Konig Pilsener Arena                          10
# The O2 Arena                                  10
# San Diego Sports Arena                        10
# Tancredo Neves Gymnasium                      10
# Concert Arena at Ferrari World                10
# Foxwoods Resort & Casino                       9
# MCAS Miramar                                   9
# Red Rock Casino Resort & Spa                   9
# CenturyLink Center                             9
# Metro Radio Arena                              9
# American Airlines Arena                        8
# CenturyTel Center                              8
# Du Arena Yas Island                            8
# Thomas and Mack Center                         8
# The Odyssey                                    8
# Continental Airlines Arena                     8
# Royal Albert Hall                              7
# Bellagio Hotel and Casino                      6
# Name: count, dtype: int64

# %%
pd.set_option('display.max_rows', 50)

# %% [markdown]
# First we need to split the data based on Venue UFC Apex. In our dataset it is represented by values "UFC APEX" and "UFC Apex".

# %%
venue_apex = df[df["Venue"].isin(["UFC Apex", "UFC APEX"])]
venue_other = df[~df["Venue"].isin(["UFC Apex", "UFC APEX"])]

# %%
venue_apex.shape
# Out:
# (1080, 52)

# %%
venue_other.shape
# Out:
# (6214, 52)

# %% [markdown]
# We can see that there is a lot more other arenas than UFC Apex. To be fair we select only the fights that happened after the first event in UFC Apex, since there could be a difference in fight finished in the early stages of UFC.

# %%
venue_apex["Date"].min()
# Out:
# '2020-05-30'

# %% [markdown]
# we can see that first fight in UFC Apex happened in 2020-05-30, so we filter non apex fights based on this date.

# %%
venue_other = venue_other[venue_other["Date"] > venue_apex["Date"].min()]

# %%
venue_other.shape
# Out:
# (901, 52)

# %% [markdown]
# We can see that there have been more UFC Apex fights (1080) after the introduction of it than fights in other arenas (901).

# %%
venue_apex_perc = venue_apex["Method"].value_counts(normalize=True)
venue_other_perc = venue_other["Method"].value_counts(normalize=True)

# %%
print(method_perc, venue_apex_perc, venue_other_perc)
# Out:
# Method
# Decision      0.468604
# KO/TKO        0.324787
# Submission    0.195092
# No Contest    0.011516
# Name: proportion, dtype: float64 Method
# Decision      0.472222
# KO/TKO        0.330556
# Submission    0.179630
# No Contest    0.017593
# Name: proportion, dtype: float64 Method
# Decision      0.496115
# KO/TKO        0.312986
# Submission    0.180910
# No Contest    0.009989
# Name: proportion, dtype: float64

# %%
data = {
    "All": method_perc.values,
    "UFC Apex": venue_apex_perc.values,
    "Other": venue_other_perc.values
}
venue_method = pd.DataFrame(data)
venue_method.index = ["Decision", "KO/TKO", "Submission", "No Contest"]
venue_method.plot(kind='bar')
plt.xlabel('Method')
plt.ylabel('Frequency')
plt.title('Difference in Method of finishes based on Venue')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# 1. We can see that about 2.5% more fights end on Decision in Venues other than UPC Apex.
# 2. We can also see there is almost double the amount of No Contest fights in the UFC Apex than in other Venues as well as in the whole dataset.
#
# This could be due to the smaller fighting space forcing fighters to engage more.

# %% [markdown]
# #### Rounds effect on method of finish.

# %%
three_rounds = ufc_data[ufc_data["Rounds"] == 3]
five_rounds = ufc_data[ufc_data["Rounds"] == 5]

# %%
print(three_rounds.shape, five_rounds.shape)
# Out:
# (6634, 52) (660, 52)

# %%
three_perc = three_rounds["Method"].value_counts(normalize=True)
five_perc = five_rounds["Method"].value_counts(normalize=True)
print(three_perc, five_perc)
# Out:
# Method
# Decision      0.477691
# KO/TKO        0.312029
# Submission    0.198523
# No Contest    0.011758
# Name: proportion, dtype: float64 Method
# KO/TKO        0.453030
# Decision      0.377273
# Submission    0.160606
# No Contest    0.009091
# Name: proportion, dtype: float64

# %% [markdown]
# We switch the order of five_perc series to fit the graph.

# %%
five_perc[0], five_perc[1] = five_perc[1], five_perc[0]
# Out:
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\2323708547.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   five_perc[0], five_perc[1] = five_perc[1], five_perc[0]
# C:\Users\Uživatel\AppData\Local\Temp\ipykernel_4576\2323708547.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   five_perc[0], five_perc[1] = five_perc[1], five_perc[0]

# %%
data = {
    "All": method_perc,
    "Three": three_perc.values,
    "Five": five_perc.values
}
venue_method = pd.DataFrame(data)
venue_method.index = ["Decision", "KO/TKO", "Submission", "No Contest"]
venue_method.plot(kind='bar')
plt.xlabel('Method')
plt.ylabel('Frequency')
plt.title('Difference in Method of finishes based on Venue')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# We can see that five round fights end by KO/TKO in 45% of cases, by Decision in 38% of cases and by submission in 16% of cases.
#
# Theres a big difference in KO/TKO and Decision finishes between five and three rounds fights.

# %% [markdown]
# #### Weightclass effect on a method of finish.

# %% [markdown]
# There are 9 main weightclasses in our dataset (115, 125, 135, 145, 155, 170, 185, 205, 265), we only select them. This way we filter out all of the catchweight fights.

# %%
df_weight = df[df["Weightclass"].isin([115, 125, 135, 145, 155, 170, 185, 205, 265])]

# %%
df_weight["Weightclass"].value_counts()
# Out:
# Weightclass
# 155.0    1260
# 170.0    1243
# 185.0     957
# 135.0     838
# 145.0     743
# 205.0     668
# 265.0     626
# 125.0     537
# 115.0     290
# Name: count, dtype: int64

# %%
weight_method = df_weight.groupby(["Weightclass", "Method"])["Result"].count().reset_index()
weight_method.sort_values("Weightclass", inplace=True)
weight_method
# Out:
#     Weightclass      Method  Result
# 0         115.0    Decision     190
# 1         115.0      KO/TKO      42
# 2         115.0  Submission      58
# 3         125.0    Decision     307
# 4         125.0      KO/TKO     114
# 5         125.0  No Contest       2
# 6         125.0  Submission     114
# 7         135.0    Decision     437
# 8         135.0      KO/TKO     222
# 9         135.0  No Contest      17
# 10        135.0  Submission     162
# 11        145.0    Decision     412
# 12        145.0      KO/TKO     200
# 13        145.0  No Contest       8
# 14        145.0  Submission     123
# 18        155.0  Submission     281
# 17        155.0  No Contest      14
# 15        155.0    Decision     605
# 16        155.0      KO/TKO     360
# 19        170.0    Decision     588
# 20        170.0      KO/TKO     403
# 21        170.0  No Contest      12
# 22        170.0  Submission     240
# 25        185.0  No Contest      10
# 23        185.0    Decision     381
# 24        185.0      KO/TKO     356
# 26        185.0  Submission     210
# 27        205.0    Decision     251
# 28        205.0      KO/TKO     292
# 29        205.0  No Contest      12
# 30        205.0  Submission     113
# 32        265.0      KO/TKO     338
# 33        265.0  No Contest       8
# 31        265.0    Decision     189
# 34        265.0  Submission      91

# %%
# Create a pivot table to prepare the data for heatmap and fill missing values with 0
pivot_table = weight_method.pivot_table(index="Weightclass", columns="Method", values="Result", fill_value=0)
pivot_table
# Out:
# Method       Decision  KO/TKO  No Contest  Submission
# Weightclass
# 115.0           190.0    42.0         0.0        58.0
# 125.0           307.0   114.0         2.0       114.0
# 135.0           437.0   222.0        17.0       162.0
# 145.0           412.0   200.0         8.0       123.0
# 155.0           605.0   360.0        14.0       281.0
# 170.0           588.0   403.0        12.0       240.0
# 185.0           381.0   356.0        10.0       210.0
# 205.0           251.0   292.0        12.0       113.0
# 265.0           189.0   338.0         8.0        91.0

# %%
pivot_table_perc = pivot_table.div(pivot_table.sum(axis=1), axis=0)
pivot_table_perc
# Out:
# Method       Decision    KO/TKO  No Contest  Submission
# Weightclass
# 115.0        0.655172  0.144828    0.000000    0.200000
# 125.0        0.571695  0.212291    0.003724    0.212291
# 135.0        0.521480  0.264916    0.020286    0.193317
# 145.0        0.554509  0.269179    0.010767    0.165545
# 155.0        0.480159  0.285714    0.011111    0.223016
# 170.0        0.473049  0.324216    0.009654    0.193081
# 185.0        0.398119  0.371996    0.010449    0.219436
# 205.0        0.375749  0.437126    0.017964    0.169162
# 265.0        0.301917  0.539936    0.012780    0.145367

# %%
sns.heatmap(data=pivot_table_perc, cmap="vlag", annot=True)
plt.xlabel('Method')
plt.ylabel('Weightclass')
plt.title('Method distribution for each Weightclass')
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# We can see that the share of Decision finishes decreases as Weightclass increases.
#
# On the other hand the share of KO/TKO finishes increases as Weightclass increases.
#
# We dont see any significant pattern in No Contest or Submission finishes.

# %%
weight_sum = weight_method.groupby(["Weightclass"])["Result"].sum().reset_index()
merged_df = pd.merge(weight_method, weight_sum, on='Weightclass')
merged_df['Result Percentage'] = merged_df['Result_x'] / merged_df['Result_y']

# %%
sns.lineplot(data=merged_df, x='Weightclass', y='Result Percentage', hue='Method',marker='o')
plt.ylabel('Share')
plt.xlabel('Weightclass')
plt.title('Method distribution for each Weightclass')
plt.xticks(merged_df['Weightclass'], rotation=0)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# We can see that share of KO/TKO finishes surpases share of Submission finishes in the 135 Weightclass and share of Decision finishes in the 205 Weightclass.

# %% [markdown]
# ### 6. Did distribution of methods change over time?

# %%
df = ufc_data

# %% [markdown]
# First we need to extract years from the Date.

# %%
year = []
def get_year():
    for date in df["Date"]:
        year.append(date.split("-")[0])
    return year
get_year()
df['Year'] = year
df.head()
# Out:
#              Fighter A          Fighter B Result  Weightclass  Rounds  \
# 0        Marcin Tybura        Tai Tuivasa    win        265.0       5
# 1         Bryan Battle         Ange Loosa     NC        170.0       3
# 2     Ovince St. Preux  Kennedy Nzechukwu    win        205.0       3
# 3  Christian Rodriguez    Isaac Dulgarian    win        145.0       3
# 4        Macy Chiasson     Pannie Kianzad    win        135.0       3
#
#       Venue        Date                          Location     Billing  \
# 0  UFC Apex  2024-03-16  Las Vegas, Nevada, United States  Main Event
# 1  UFC Apex  2024-03-16  Las Vegas, Nevada, United States     Co-Main
# 2  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 3  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
# 4  UFC Apex  2024-03-16  Las Vegas, Nevada, United States   Main Card
#
#                             Event Name        Referee          Description  \
# 0  UFC Fight Night: Tuivasa vs. Tybura      Herb Dean     Rear Naked Choke
# 1  UFC Fight Night: Tuivasa vs. Tybura   Mike Beltran  Accidental Eye Poke
# 2  UFC Fight Night: Tuivasa vs. Tybura     Mark Smith                Split
# 3  UFC Fight Night: Tuivasa vs. Tybura  Chris Tognoni                Split
# 4  UFC Fight Night: Tuivasa vs. Tybura     Mark Smith     Rear Naked Choke
#
#        Method  Finish  Odds A Title A  Weight A  Age A  Height A  Reach A  \
# 0  Submission       1    -105     NaN     247.0     38     191.0    198.0
# 1  No Contest       0    -180     NaN     170.0     29     185.0    196.0
# 2    Decision       0     500     NaN     206.0     40     191.0    203.0
# 3    Decision       0     165     NaN     145.0     26     170.0    180.0
# 4  Submission       1    -230     NaN     135.5     32     180.0    183.0
#
#    KO win A  KO loss A  Sub win A  Sub loss A  Dec win A  Dec loss A  Draws A  \
# 0         9          5          6           0          9           3        0
# 1         3          0          5           1          2           1        0
# 2        12          5          8           3          6           9        0
# 3         3          0          4           0          3           1        0
# 4         2          1          2           1          4           1        0
#
#    UFC win A  UFC loss A  UFC draws A  Nationality A       Nick A  \
# 0         11           7            0         Poland        Tybur
# 1          5           1            0  United States  The Butcher
# 2         14          12            0  United States          OSP
# 3          3           1            0  United States       CeeRod
# 4          6           3            0  United States          NaN
#
#           Odds cat A  Odds B Title B  Weight B  Age B  Height B  Reach B  \
# 0          Near Even    -115     NaN     265.5     31     188.0    191.0
# 1    Slight Favorite     150     NaN     171.0     29     178.0    188.0
# 2     Heavy Underdog    -700     NaN     205.0     31     196.0    211.0
# 3    Slight Underdog    -200     NaN     145.5     27     170.0    180.0
# 4  Moderate Favorite     190     NaN     136.0     32     170.0    168.0
#
#    KO win B  KO loss B  Sub win B  Sub loss B  Dec win B  Dec loss B  Draws B  \
# 0        13          3          0           2          1           1        0
# 1         5          0          1           0          4           3        0
# 2         8          2          1           1          3           1        0
# 3         4          0          2           0          0           0        0
# 4         3          1          0           2         13           4        0
#
#    UFC win B  UFC loss B  UFC draws B                          Nationality B  \
# 0          8           6            0                              Australia
# 1          2           1            0  Congo, The Democratic Republic of the
# 2          6           4            0                          United States
# 3          1           0            0                          United States
# 4          5           4            0                                 Sweden
#
#                Nick B         Odds cat B  Year
# 0             Bam Bam          Near Even  2024
# 1      The Last Ninja    Slight Underdog  2024
# 2     American Savage      Huge Favorite  2024
# 3  The MidWest Choppa  Moderate Favorite  2024
# 4              Banzai    Slight Underdog  2024

# %% [markdown]
# Now we count the number of methods for each year.

# %%
year_method = df.groupby(["Method", "Year"])["Result"].count().reset_index()
year_method
# Out:
#         Method  Year  Result
# 0     Decision  2001      10
# 1     Decision  2002      15
# 2     Decision  2003      14
# 3     Decision  2004      10
# 4     Decision  2005      19
# ..         ...   ...     ...
# 85  Submission  2020      81
# 86  Submission  2021      73
# 87  Submission  2022      98
# 88  Submission  2023     102
# 89  Submission  2024      19
#
# [90 rows x 3 columns]

# %%
year_sum = year_method.groupby(["Year"])["Result"].sum().reset_index()
year_sum
# Out:
#     Year  Result
# 0   2001      32
# 1   2002      53
# 2   2003      41
# 3   2004      39
# 4   2005      80
# 5   2006     158
# 6   2007     171
# 7   2008     201
# 8   2009     215
# 9   2010     253
# 10  2011     300
# 11  2012     341
# 12  2013     386
# 13  2014     503
# 14  2015     473
# 15  2016     493
# 16  2017     457
# 17  2018     474
# 18  2019     516
# 19  2020     456
# 20  2021     509
# 21  2022     511
# 22  2023     520
# 23  2024     112

# %%
merged_df = pd.merge(year_method, year_sum, on='Year')
merged_df['Result Percentage'] = merged_df['Result_x'] / merged_df['Result_y']

# %%
merged_df
# Out:
#         Method  Year  Result_x  Result_y  Result Percentage
# 0     Decision  2001        10        32           0.312500
# 1       KO/TKO  2001        15        32           0.468750
# 2   Submission  2001         7        32           0.218750
# 3     Decision  2002        15        53           0.283019
# 4       KO/TKO  2002        27        53           0.509434
# ..         ...   ...       ...       ...                ...
# 85  Submission  2023       102       520           0.196154
# 86    Decision  2024        57       112           0.508929
# 87      KO/TKO  2024        33       112           0.294643
# 88  No Contest  2024         3       112           0.026786
# 89  Submission  2024        19       112           0.169643
#
# [90 rows x 5 columns]

# %%
sns.lineplot(data=merged_df, x='Year', y='Result Percentage', hue='Method',marker='o')
plt.ylabel('Share')
plt.xlabel('Year')
plt.title('Method distribution for each Year')
plt.xticks(rotation=60)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# We can see that the distribution of methods changed dramatically between the years 2003 and 2011.
# 1. In 2001 the most prevelant finish method was KO/TKO with about 48%, followed by Decision with about 30% and Submission about 22%.
# 2. In 2004 there is a big spike in Submissions reaching about 30% and a decline of Decisions falling to 25%.
# 3. In 2006 all the major finishing methods have the same share of about 33%.
# 4. From 2007 to 2011 Submissions were on a decline, finally settling slightly under 20% level.
# 5. In 2008 KO/TKO finish had a big spike reaching 40% level, but falling down in the next few years to settle around 30%.
# 6. Decision wins were on a rise from 2005 all the way to 2010  with a slight dip in 2008.
#
# Since 2011 the methods stabilized with Decisions around 50%, KO/TKOs around 30% and Submissions around 20%.

# %% [markdown]
# ### 7. Is there a correlation between previous results and finishing method of a fight?

# %% [markdown]
# We will do this analysis only on fights with a winner.

# %%
df_win = ufc_data[ufc_data["Result"] == "win"]

# %% [markdown]
# First we need to convert Methods into their encoded version.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df_encoded = pd.get_dummies(df_win, columns=['Method'], prefix='Encoded')

# %%
df_encoded.columns
# Out:
# Index(['Fighter A', 'Fighter B', 'Result', 'Weightclass', 'Rounds', 'Venue',
#        'Date', 'Location', 'Billing', 'Event Name', 'Referee', 'Description',
#        'Finish', 'Odds A', 'Title A', 'Weight A', 'Age A', 'Height A',
#        'Reach A', 'KO win A', 'KO loss A', 'Sub win A', 'Sub loss A',
#        'Dec win A', 'Dec loss A', 'Draws A', 'UFC win A', 'UFC loss A',
#        'UFC draws A', 'Nationality A', 'Nick A', 'Odds cat A', 'Odds B',
#        'Title B', 'Weight B', 'Age B', 'Height B', 'Reach B', 'KO win B',
#        'KO loss B', 'Sub win B', 'Sub loss B', 'Dec win B', 'Dec loss B',
#        'Draws B', 'UFC win B', 'UFC loss B', 'UFC draws B', 'Nationality B',
#        'Nick B', 'Odds cat B', 'Year', 'Encoded_Decision', 'Encoded_KO/TKO',
#        'Encoded_Submission'],
#       dtype='object')

# %%
df_encoded[['KO win A', 'KO loss A', 'Sub win A', 'Sub loss A', 'Dec win A', 'Dec loss A', 'Draws A', 'KO win B', 'KO loss B', 'Sub win B', 'Sub loss B', 'Dec win B',
       'Dec loss B', 'Draws B', 'Encoded_Decision',
       'Encoded_KO/TKO', 'Encoded_Submission']].corr()
# Out:
#                     KO win A  KO loss A  Sub win A  Sub loss A  Dec win A  \
# KO win A            1.000000   0.357326  -0.058692    0.305344   0.154424
# KO loss A           0.357326   1.000000   0.285979    0.142908   0.140411
# Sub win A          -0.058692   0.285979   1.000000    0.217044   0.083280
# Sub loss A          0.305344   0.142908   0.217044    1.000000   0.200461
# Dec win A           0.154424   0.140411   0.083280    0.200461   1.000000
# Dec loss A          0.208008   0.189631   0.321397    0.185871   0.419903
# Draws A             0.091529   0.044840   0.187241    0.102801   0.117091
# KO win B            0.259703   0.143510   0.023855    0.050258   0.103963
# KO loss B           0.166711   0.141903   0.025723    0.054998   0.021091
# Sub win B           0.039813   0.039789   0.107947    0.045157   0.083851
# Sub loss B          0.029448   0.026459   0.059862    0.051372   0.044414
# Dec win B           0.077184   0.008174   0.070571    0.016218   0.225180
# Dec loss B          0.079710   0.041331   0.058723    0.070263   0.157381
# Draws B             0.011846   0.028510   0.060180    0.032378   0.033386
# Encoded_Decision   -0.059153  -0.047797  -0.066453   -0.018486   0.158611
# Encoded_KO/TKO      0.188443   0.039404  -0.118090    0.031531  -0.080804
# Encoded_Submission -0.148209   0.013312   0.222334   -0.014059  -0.103078
#
#                     Dec loss A   Draws A  KO win B  KO loss B  Sub win B  \
# KO win A              0.208008  0.091529  0.259703   0.166711   0.039813
# KO loss A             0.189631  0.044840  0.143510   0.141903   0.039789
# Sub win A             0.321397  0.187241  0.023855   0.025723   0.107947
# Sub loss A            0.185871  0.102801  0.050258   0.054998   0.045157
# Dec win A             0.419903  0.117091  0.103963   0.021091   0.083851
# Dec loss A            1.000000  0.235695  0.065399   0.048421   0.053483
# Draws A               0.235695  1.000000 -0.005173  -0.001400   0.012644
# KO win B              0.065399 -0.005173  1.000000   0.385613  -0.043594
# KO loss B             0.048421 -0.001400  0.385613   1.000000   0.279101
# Sub win B             0.053483  0.012644 -0.043594   0.279101   1.000000
# Sub loss B            0.061911  0.015504  0.302524   0.156535   0.243043
# Dec win B             0.090717 -0.004175  0.185158   0.159288   0.106456
# Dec loss B            0.112822  0.015676  0.267597   0.183154   0.303271
# Draws B               0.032276  0.020899  0.081314   0.096357   0.216574
# Encoded_Decision      0.034385 -0.001913 -0.065118  -0.093785   0.017471
# Encoded_KO/TKO       -0.034635 -0.016133  0.071214   0.140642   0.017105
# Encoded_Submission   -0.002164  0.021413 -0.002533  -0.048541  -0.042015
#
#                     Sub loss B  Dec win B  Dec loss B   Draws B  \
# KO win A              0.029448   0.077184    0.079710  0.011846
# KO loss A             0.026459   0.008174    0.041331  0.028510
# Sub win A             0.059862   0.070571    0.058723  0.060180
# Sub loss A            0.051372   0.016218    0.070263  0.032378
# Dec win A             0.044414   0.225180    0.157381  0.033386
# Dec loss A            0.061911   0.090717    0.112822  0.032276
# Draws A               0.015504  -0.004175    0.015676  0.020899
# KO win B              0.302524   0.185158    0.267597  0.081314
# KO loss B             0.156535   0.159288    0.183154  0.096357
# Sub win B             0.243043   0.106456    0.303271  0.216574
# Sub loss B            1.000000   0.230211    0.188614  0.088348
# Dec win B             0.230211   1.000000    0.476158  0.166456
# Dec loss B            0.188614   0.476158    1.000000  0.232964
# Draws B               0.088348   0.166456    0.232964  1.000000
# Encoded_Decision     -0.051633   0.104991    0.134066  0.020555
# Encoded_KO/TKO       -0.020312  -0.052492   -0.068232 -0.001191
# Encoded_Submission    0.088518  -0.069405   -0.087206 -0.024301
#
#                     Encoded_Decision  Encoded_KO/TKO  Encoded_Submission
# KO win A                   -0.059153        0.188443           -0.148209
# KO loss A                  -0.047797        0.039404            0.013312
# Sub win A                  -0.066453       -0.118090            0.222334
# Sub loss A                 -0.018486        0.031531           -0.014059
# Dec win A                   0.158611       -0.080804           -0.103078
# Dec loss A                  0.034385       -0.034635           -0.002164
# Draws A                    -0.001913       -0.016133            0.021413
# KO win B                   -0.065118        0.071214           -0.002533
# KO loss B                  -0.093785        0.140642           -0.048541
# Sub win B                   0.017471        0.017105           -0.042015
# Sub loss B                 -0.051633       -0.020312            0.088518
# Dec win B                   0.104991       -0.052492           -0.069405
# Dec loss B                  0.134066       -0.068232           -0.087206
# Draws B                     0.020555       -0.001191           -0.024301
# Encoded_Decision            1.000000       -0.662619           -0.469280
# Encoded_KO/TKO             -0.662619        1.000000           -0.350412
# Encoded_Submission         -0.469280       -0.350412            1.000000

# %% [markdown]
# From the correlation table we can see that there are some variables that correlate with Methods of finish more than others. Althought the correlation coefficients are weak, they are bigger than correlation coefficients in the rest of the data.
# 1. The highest corr. coefs. in the Decision column are "Dec win A" (0.16) , "Dec loss B" (0.13) and "Dec win B" (0.1). This means that for method Decision there is strongest relationship with decision wins of both fighters and decision losses of losing fighter.
# 2. The highest corr. coefs. in the KO/TKO column are "KO win A" (0.19) and "KO loss B" (0.14). This means that for method KO/TKO there is strongest relationship with KO wins of winning fighter and KO losses of losing fighter.
# 3. The highest corr. coefs. in the Submission column are "Sub win A" (0.22), "KO win A" (-0.15), "Dec win A" (-0.1). This means that for method Submission there is strongest relationship with Submission, KO and Decision wins of winning fighter.
#
# It is interesting that KO/TKO and Decision columns have at least some relationship (over 0.1) with both winning and losing fighters variables, but Submission column has relationship only with the winning fighter variables.

# %% [markdown]
# ### 8. What is most likely round a fight ends prematurely?

# %%
df = ufc_data

# %%
finish_perc = df["Finish"].value_counts(normalize=True)

# %%
finish_perc
# Out:
# Finish
# 0    0.480121
# 1    0.266246
# 2    0.163833
# 3    0.079929
# 4    0.005758
# 5    0.004113
# Name: proportion, dtype: float64

# %%
finish_perc.plot(kind='bar')
plt.xlabel('Round')
plt.ylabel('Proportion')
plt.title('Barplot of Finish proportion')
plt.xticks(rotation=0)
plt.show()

# %%
three_rounds = df[df["Rounds"] == 3]
five_rounds = df[df["Rounds"] == 5]

# %%
finish_three_perc = three_rounds["Finish"].value_counts(normalize=True)
finish_five_perc = five_rounds["Finish"].value_counts(normalize=True)

# %%
finish_three_perc
# Out:
# Finish
# 0    0.489448
# 1    0.269219
# 2    0.164154
# 3    0.077178
# Name: proportion, dtype: float64

# %%
finish_three_perc.plot(kind='bar')
finish_three_perc.plot( color='red', marker='.', linestyle='-', linewidth=2, markersize=8, label='Line Plot')
plt.xlabel('Round')
plt.ylabel('Proportion')
plt.title('Barplot of Finish proportion for three round fights')
plt.xticks(rotation=0)
plt.show()

# %%
finish_five_perc
# Out:
# Finish
# 0    0.386364
# 1    0.236364
# 2    0.160606
# 3    0.107576
# 4    0.063636
# 5    0.045455
# Name: proportion, dtype: float64

# %%
finish_five_perc.plot(kind='bar')
finish_five_perc.plot(color='red', marker='.', linestyle='-', linewidth=2, markersize=8, label='Line Plot')
plt.xlabel('Round')
plt.ylabel('Proportion')
plt.title('Barplot of Finish proportion for five round fights')
plt.xticks(rotation=0)
plt.show()

# %%
print(finish_perc, finish_three_perc, finish_five_perc)
# Out:
# Finish
# 0    0.480121
# 1    0.266246
# 2    0.163833
# 3    0.079929
# 4    0.005758
# 5    0.004113
# Name: proportion, dtype: float64 Finish
# 0    0.489448
# 1    0.269219
# 2    0.164154
# 3    0.077178
# Name: proportion, dtype: float64 Finish
# 0    0.386364
# 1    0.236364
# 2    0.160606
# 3    0.107576
# 4    0.063636
# 5    0.045455
# Name: proportion, dtype: float64

# %% [markdown]
# In both five and three round fights, the likelihood of fight ending decreases round by round.
#
# It is interesting that the chance a fight ends in third round is bigger in five round fights.

# %% [markdown]
# ### 9. Is there any predictor for a draw?

# %%
df_draw = ufc_data[ufc_data["Result"] == "draw"]
df_draw.shape
# Out:
# (53, 53)

# %%
df_draw["Rounds"].value_counts()
# Out:
# Rounds
# 3    46
# 5     7
# Name: count, dtype: int64

# %% [markdown]
# There is not enough data to do any effective analysis for draws.

# %% [markdown]
# ### Unfinished work

# %% [markdown]
# In draws results, fighters A and B are interchangeable, so we copy the values from fighter A to fighter B and opposite.

# %%
df_draw.columns
# Out:
# Index(['Fighter A', 'Fighter B', 'Result', 'Weightclass', 'Rounds', 'Venue',
#        'Date', 'Location', 'Billing', 'Event Name', 'Referee', 'Description',
#        'Method', 'Finish', 'Odds A', 'Title A', 'Weight A', 'Age A',
#        'Height A', 'Reach A', 'KO win A', 'KO loss A', 'Sub win A',
#        'Sub loss A', 'Dec win A', 'Dec loss A', 'Draws A', 'UFC win A',
#        'UFC loss A', 'UFC draws A', 'Nationality A', 'Nick A', 'Odds cat A',
#        'Odds B', 'Title B', 'Weight B', 'Age B', 'Height B', 'Reach B',
#        'KO win B', 'KO loss B', 'Sub win B', 'Sub loss B', 'Dec win B',
#        'Dec loss B', 'Draws B', 'UFC win B', 'UFC loss B', 'UFC draws B',
#        'Nationality B', 'Nick B', 'Odds cat B', 'Year'],
#       dtype='object')

# %% [markdown]
# Make a copy of draw dataframe and change the column names to be opposite for fighter A and B.

# %%
df_copy = df_draw.copy()

# %%
df_copy.columns=['Fighter B', 'Fighter A', 'Result', 'Weightclass', 'Rounds', 'Venue',
       'Date', 'Location', 'Billing', 'Event Name', 'Referee', 'Description',
       'Method', 'Finish', 'Odds B', 'Title B', 'Weight B', 'Age B',
       'Height B', 'Reach B', 'KO win B', 'KO loss B', 'Sub win B',
       'Sub loss B', 'Dec win B', 'Dec loss B', 'Draws B', 'UFC win B',
       'UFC loss B', 'UFC draws B', 'Nationality B', 'Nick B', 'Odds cat B',
       'Odds A', 'Title A', 'Weight A', 'Age A', 'Height A', 'Reach A',
       'KO win A', 'KO loss A', 'Sub win A', 'Sub loss A', 'Dec win A',
       'Dec loss A', 'Draws A', 'UFC win A', 'UFC loss A', 'UFC draws A',
       'Nationality A', 'Nick A', 'Odds cat A', "Year"]

# %%
df_copy.head()
# Out:
#           Fighter B             Fighter A Result  Weightclass  Rounds  \
# 169  Nazim Sadykhov  Viacheslav Borshchev   draw        155.0       3
# 179  Elizeu Zaleski    Rinat Fakhretdinov   draw        170.0       3
# 229    Alexa Grasso  Valentina Shevchenko   draw        125.0       5
# 532     Jai Herbert         Ľudovít Klein   draw        155.0       3
# 586     Jimmy Crute      Alonzo Menifield   draw        205.0       3
#
#                      Venue        Date  \
# 169  Madison Square Garden  2023-11-11
# 179   Ibirapuera Gymnasium  2023-11-04
# 229         T-Mobile Arena  2023-09-16
# 532               O2 Arena  2023-03-18
# 586              RAC Arena  2023-02-11
#
#                                    Location     Billing  \
# 169  New York City, New York, United States      Prelim
# 179                       Sao Paulo, Brazil      Prelim
# 229        Las Vegas, Nevada, United States  Main Event
# 532                         London, England      Prelim
# 586                Perth, Western Australia   Main Card
#
#                                    Event Name            Referee Description  \
# 169            UFC 295: Procházka vs. Pereira     Keith Peterson    Majority
# 179        UFC Fight Night: Almeida vs. Lewis  Fernando Portella    Majority
# 229  UFC Fight Night: Grasso vs. Shevchenko 2          Herb Dean       Split
# 532              UFC 286: Edwards vs. Usman 3      Rich Mitchell    Majority
# 586        UFC 284: Makhachev vs. Volkanovski       Marc Goddard    Majority
#
#        Method  Finish  Odds B   Title B  Weight B  Age B  Height B  Reach B  \
# 169  Decision       0    -135       NaN     155.6     29     178.0    175.0
# 179  Decision       0     280       NaN     171.0     36     180.0    185.0
# 229  Decision       0     145  Champion     124.5     30     165.0    168.0
# 532  Decision       0     170       NaN     156.0     34     185.0    196.0
# 586  Decision       0    -190       NaN     204.5     26     188.0    188.0
#
#      KO win B  KO loss B  Sub win B  Sub loss B  Dec win B  Dec loss B  \
# 169         6          0          2           1          1           0
# 179        14          1          3           2          7           4
# 229         4          0          2           1         10           2
# 532         9          3          1           1          2           0
# 586         5          2          4           1          3           0
#
#      Draws B  UFC win B  UFC loss B  UFC draws B Nationality B  \
# 169        0          2           0            0    Azerbaijan
# 179        0         10           3            0        Brazil
# 229        0          8           3            0        Mexico
# 532        0          2           3            0       England
# 586        0          4           3            0     Australia
#
#                        Nick B         Odds cat B  Odds A     Title A  \
# 169                Black Wolf    Slight Favorite     115         NaN
# 179                  Capoeira  Moderate Underdog    -370         NaN
# 229                       NaN    Slight Underdog    -175  Challenger
# 532  The Black Country Banger    Slight Underdog    -210         NaN
# 586                 The Brute    Slight Favorite     155         NaN
#
#      Weight A  Age A  Height A  Reach A  KO win A  KO loss A  Sub win A  \
# 169     154.8     31     180.0    175.0         6          0          0
# 179     170.5     32     183.0    188.0        11          0          6
# 229     124.5     35     165.0    166.0         8          1          7
# 532     156.0     28     170.0    184.0         8          1          8
# 586     205.0     35     183.0    193.0        10          1          2
#
#      Sub loss A  Dec win A  Dec loss A  Draws A  UFC win A  UFC loss A  \
# 169           0          1           3        0          2           2
# 179           0          4           1        0          3           0
# 229           1          8           2        0         12           3
# 532           2          3           1        0          3           2
# 586           0          1           2        0          6           3
#
#      UFC draws A  Nationality A         Nick A         Odds cat A  Year
# 169            0  United States          Slava          Near Even  2023
# 179            0         Russia      Gladiator  Moderate Favorite  2023
# 229            0     Kyrgyzstan         Bullet    Slight Favorite  2023
# 532            0       Slovakia  Mr. Highlight  Moderate Favorite  2023
# 586            0  United States         Atomic    Slight Underdog  2023

# %%
df_draw.head()
# Out:
#           Fighter A             Fighter B Result  Weightclass  Rounds  \
# 169  Nazim Sadykhov  Viacheslav Borshchev   draw        155.0       3
# 179  Elizeu Zaleski    Rinat Fakhretdinov   draw        170.0       3
# 229    Alexa Grasso  Valentina Shevchenko   draw        125.0       5
# 532     Jai Herbert         Ľudovít Klein   draw        155.0       3
# 586     Jimmy Crute      Alonzo Menifield   draw        205.0       3
#
#                      Venue        Date  \
# 169  Madison Square Garden  2023-11-11
# 179   Ibirapuera Gymnasium  2023-11-04
# 229         T-Mobile Arena  2023-09-16
# 532               O2 Arena  2023-03-18
# 586              RAC Arena  2023-02-11
#
#                                    Location     Billing  \
# 169  New York City, New York, United States      Prelim
# 179                       Sao Paulo, Brazil      Prelim
# 229        Las Vegas, Nevada, United States  Main Event
# 532                         London, England      Prelim
# 586                Perth, Western Australia   Main Card
#
#                                    Event Name            Referee Description  \
# 169            UFC 295: Procházka vs. Pereira     Keith Peterson    Majority
# 179        UFC Fight Night: Almeida vs. Lewis  Fernando Portella    Majority
# 229  UFC Fight Night: Grasso vs. Shevchenko 2          Herb Dean       Split
# 532              UFC 286: Edwards vs. Usman 3      Rich Mitchell    Majority
# 586        UFC 284: Makhachev vs. Volkanovski       Marc Goddard    Majority
#
#        Method  Finish  Odds A   Title A  Weight A  Age A  Height A  Reach A  \
# 169  Decision       0    -135       NaN     155.6     29     178.0    175.0
# 179  Decision       0     280       NaN     171.0     36     180.0    185.0
# 229  Decision       0     145  Champion     124.5     30     165.0    168.0
# 532  Decision       0     170       NaN     156.0     34     185.0    196.0
# 586  Decision       0    -190       NaN     204.5     26     188.0    188.0
#
#      KO win A  KO loss A  Sub win A  Sub loss A  Dec win A  Dec loss A  \
# 169         6          0          2           1          1           0
# 179        14          1          3           2          7           4
# 229         4          0          2           1         10           2
# 532         9          3          1           1          2           0
# 586         5          2          4           1          3           0
#
#      Draws A  UFC win A  UFC loss A  UFC draws A Nationality A  \
# 169        0          2           0            0    Azerbaijan
# 179        0         10           3            0        Brazil
# 229        0          8           3            0        Mexico
# 532        0          2           3            0       England
# 586        0          4           3            0     Australia
#
#                        Nick A         Odds cat A  Odds B     Title B  \
# 169                Black Wolf    Slight Favorite     115         NaN
# 179                  Capoeira  Moderate Underdog    -370         NaN
# 229                       NaN    Slight Underdog    -175  Challenger
# 532  The Black Country Banger    Slight Underdog    -210         NaN
# 586                 The Brute    Slight Favorite     155         NaN
#
#      Weight B  Age B  Height B  Reach B  KO win B  KO loss B  Sub win B  \
# 169     154.8     31     180.0    175.0         6          0          0
# 179     170.5     32     183.0    188.0        11          0          6
# 229     124.5     35     165.0    166.0         8          1          7
# 532     156.0     28     170.0    184.0         8          1          8
# 586     205.0     35     183.0    193.0        10          1          2
#
#      Sub loss B  Dec win B  Dec loss B  Draws B  UFC win B  UFC loss B  \
# 169           0          1           3        0          2           2
# 179           0          4           1        0          3           0
# 229           1          8           2        0         12           3
# 532           2          3           1        0          3           2
# 586           0          1           2        0          6           3
#
#      UFC draws B  Nationality B         Nick B         Odds cat B  Year
# 169            0  United States          Slava          Near Even  2023
# 179            0         Russia      Gladiator  Moderate Favorite  2023
# 229            0     Kyrgyzstan         Bullet    Slight Favorite  2023
# 532            0       Slovakia  Mr. Highlight  Moderate Favorite  2023
# 586            0  United States         Atomic    Slight Underdog  2023

# %% [markdown]
# Combine the original and flipped dataframes.

# %%
df_combined = pd.concat([df_draw, df_copy], ignore_index=True)
df_combined.head()
